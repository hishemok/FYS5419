# %% [markdown]
# # Braiding project for Quantum Computation course

# %% [markdown]
# ## a) Qubits vs Fermions
#
# The usual model of quantum computation is expressed in terms of qubits and Pauli operators $X$ $Y$ and $Z$. A single fermionic mode is also a two-level system (either occupied or not), but is quite different from a qubit. Two key features are fermionic parity conservation and the anti-commutation relations.
#
# Parity conservation means that we can't make superpositions between states of even and odd fermionic numbers. Therefore, a single fermionic mode can't be used as a qubit. It is a two-level system, but we are not allowed to make superpostions between the two states.
#
# The anti-commutation relations imply that fermionic operators are non-local, which means they do not map cleanly to the local Pauli gates.
#
# Let's take system with two fermionic, $c_1$ and $c_2$. The Hilbert space is 4-dimensional, but because of parity conservation, we can consider the two subspaces of even and odd total parity separately. Let's take the odd parity subspace to be concrete. This is a two level system, spanned by the states $\ket{+ -}$ (left mode is unoccupied (even parity) and the right mode is occupied (odd parity)) and $\ket{ - +}$. We can write down the standard Pauli operators in this space, i.e $X = \begin{pmatrix} 0 &1\\1&0 \end{pmatrix}$.
#
#  - Express the Pauli operators in terms of the fermions $c_1$ and $c_2$.
#  - Define four hermitian Majorana operators $γ_0,γ_1,γ_2,γ_3$ with the mapping $c_k=\displaystyle \frac{γ_{2k-2} + iγ_{2k-1}}{2}$.
#  - What are the anti-commutation relations between the Majoranas?
#  - Express the Pauli operators in terms of Majorana operators.

# %% [markdown]
# ### Pauli gates in terms of fermions
# $c_i$ ammihilates a fermion in mode $i$ and $c_i^{†}$ creates a fermion in mode $i$.
#
# We know that the Pauli $X$ gate flips the bit.
# From this we can express it as:
# $$X = c_1^{†} c_2 + c_2^{†} c_1 $$
#
# The Pauli $Y$ gate does an imaginary bitflip
# $$ Y = -i(c_1^{†} c_2 - c_2^{†} c_1)$$
#
# And $Z$ changes the sign of the $\ket{1}$ and leaves $\ket{0}$ unchanged
# $$Z = c_1^{†}c_1 - c_2^{†} c_2$$
#
# ### Define four majorana operators
# $$c_1= \frac{γ_0 + iγ_1}{2} \quad c_1^{†}= \frac{γ_0 - iγ_1}{2} $$
# $$c_2= \frac{γ_2 + iγ_3}{2} \quad c_2^{†}= \frac{γ_2 - iγ_3}{2} $$
#
# ### The anti-commutation relations between Majoranas
# Hermitian: $γ_j = γ_j^{†}$
#
# Canonical anti-commutation: $\{γ_j,γ_k\}=2δ_{jk}$
#
# Meaning:
# $γ_j^{2}=1$ and
# $γ_j γ_k = -γ_k γ_j$ for $j≠ k$

# %% [markdown]
# ### Express Pauli operators in terms of Majorana Operators
# Firstly $X$
# $$
# X = c_1^{†} c_2 + c_2^{†} c_1 = \frac{γ_0 - iγ_1}{2} \frac{γ_2 + iγ_3}{2}  +  \frac{γ_2 - iγ_3}{2}\frac{γ_0 + iγ_1}{2}
# $$
# $$
# =\frac{1}{4} (γ_0γ_2 + iγ_0γ_3 - iγ_1γ_2 + γ_1γ_3 + γ_2γ_0 + iγ_2γ_1 -iγ_3γ_0 + γ_3γ_1)
# $$
# Using the anti-commutation rules
# $$
# =\frac{1}{4} ( iγ_0γ_3 - iγ_1γ_2  + iγ_2γ_1 -iγ_3γ_0 )
# $$
# $$
# =\frac{i}{2} ( γ_0γ_3 - γ_1γ_2 )
# $$
#
# From the odd parity subspace we have the total Parity operator $P_{tot}=i²γ_0γ_1γ_2γ_3=-I$. From this we can try to find a relation between $γ_0γ_3$ and $γ_1γ_2$.
# $$
# γ_0γ_1γ_2γ_3 = I\\
# γ_0γ_1γ_2γ_3 γ_3 = γ_3\\
# γ_0γ_1γ_2 = γ_3 \\
# γ_1γ_2γ_0γ_0 = γ_3γ_0\\
# γ_1γ_2=γ_3γ_0=-γ_0γ_3
# $$
# Thus $X$ becomes
# $$
# X = -iγ_1γ_2 \text{ or } X = iγ_0γ_3
# $$

# %% [markdown]
# Now for $Y$
#
# $$ Y = -i(c_1^{†} c_2 - c_2^{†} c_1) = -i (  \frac{γ_0 - iγ_1}{2} \frac{γ_2 + iγ_3}{2}  -  \frac{γ_2 - iγ_3}{2}\frac{γ_0 + iγ_1}{2} )
# $$
#
# $$
# = \frac{-i}{4} (γ_0γ_2 + iγ_0γ_3 - iγ_1γ_2 + γ_1γ_3 - γ_2γ_0 - iγ_2γ_1 +iγ_3γ_0 - γ_3γ_1)
# $$
# $$
# = \frac{-i}{2} (γ_0γ_2 + γ_1γ_3)
# $$
#
# $$
# Y = -i γ_0γ_2 \text{ or } Y = -i γ_1γ_3
# $$

# %% [markdown]
# And lastly for $Z$
#
# $$
# Z = c_1^{†}c_1 - c_2^{†} c_2 = \frac{γ_0 - iγ_1}{2}\frac{γ_0 + iγ_1}{2} - \frac{γ_2 - iγ_3}{2}\frac{γ_2 + iγ_3}{2}
# $$
# $$
# = \frac{1}{4} (γ_0γ_0 +iγ_0γ_1 -iγ_1γ_0 + γ_1γ_1 - γ_2γ_2 -iγ_2γ_3 + iγ_3γ_2 - γ_3γ_3)
# $$
# $$
# = \frac{i}{2} (γ_0γ_1 + γ_2γ_3)
# $$
#
# $$
# Z = iγ_0γ_1 \text{ or } Z= iγ_2γ_3
# $$

# %% [markdown]
# ## b) Majorana Exchange gates
#
# Let's take a step towards braiding and define Majorana exchange operators
#  - Find unitaries $B_{ij}$ that exchange the Majoranas $γ_i$ and $γ_j$, meaning it should act as
#  $$
#  B_{ij} γ_i B_{ij}^{†} = γ_j
#  $$
#   $$
#  B_{ij} γ_j B_{ij}^{†} = -γ_i
#  $$
#  and trivially on other operators. Express the gates in terms of $γ_i$ and  $γ_j$ as well as in the basis $\ket{+ -}$, $\ket{-+}$
#
#  - Check the $B_{ij}^{2}$ of these operators, how are they related to the Pauli operators?
#  - Express the Hadamard gate in terms of exchange gates
#  - Bonus: Do the same relations hold in the even parity sector?

# %% [markdown]
# ### Find unitaries
#
# If $\displaystyle  B_{ij} = \sqrt{\frac{i}{2}} (1-γ_iγ_j)$, then $\displaystyle  B_{ij}^{†} = \frac{1-i}{2} (1+γ_iγ_j)$ from $(AB)^{†} = B^{†}A^{†}$
#
# In order to express the gates in terms of the basis $\ket{+ - } $, $\ket{-+}$, I will project the matrix $B_{ij}$ into the $2× 2$ odd subspace.
# In the full $4× 4$ Hilbert space, $\ket{+-} = [0,1,0,0]^T$ and $\ket{+-} = [0,0,1,0]^T$.
#
# $$
# B_{ij}^{(2\times 2)} =
# \begin{pmatrix}
#   \bra{+ - } B_{ij} \ket{+-} & \bra{+ - } B_{ij} \ket{-+}\\
#   \bra{- + } B_{ij} \ket{+-} & \bra{- + } B_{ij} \ket{-+}
# \end{pmatrix}
# $$
# By doing this, we obtain a few different braiding matrices. Comparing them to the pauli matrices we see that
# $$
# \begin{aligned}
# B²_{12} &= X\\
# B²_{03} &= -X\\
# B²_{02} &= -Y\\
# B²_{13} &= -Y\\
# B²_{01} &= Z\\
# B²_{23} &= -Z
# \end{aligned}
# $$

# %% [markdown]
# ### Imports and configs

# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit

np.set_printoptions(precision=3, suppress=True)

plt.rcParams.update({
    'font.size': 12,
    "figure.figsize":(8,6),
    "axes.grid": True,
    "grid.color": "#cccccc",
    "grid.linestyle": "--",
    "axes.prop_cycle": plt.cycler(color=['#0f7e92', '#b90636', '#11793e', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])
})

# %% [markdown]
# ### Braiding operator in terms of Majoranas

# %%
"""Check properties of the Braiding operators"""
def pauli_matrices():
    X = np.array([[0, 1], [1, 0]])
    Y = np.array([[0, -1j], [1j, 0]])
    Z = np.array([[1, 0], [0, -1]])
    I = np.eye(2)
    return X, Y, Z, I

X, Y, Z, I = pauli_matrices()

Hadamard = np.array([[1, 1], [1, -1]]) / np.sqrt(2)

def majorana_operators():
    """
    Using the standard Majorana representation from JW transformation for simplicity
    """
    gamma0 = np.kron(X,I)
    gamma1 = np.kron(Y,I)
    gamma2 = np.kron(Z,X)
    gamma3 = np.kron(Z,Y)
    return gamma0, gamma1, gamma2, gamma3

def braiding_operators(i,j):
    """
    Returns braiding operators for adjacent Majorana operators
    """
    return np.sqrt(1j/2) * (np.kron(I,I) - i@j)


def test_braiding_ops():
    """
    Test the braiding operators
    """
    gamma0, gamma1, gamma2, gamma3 = majorana_operators()
    b01 = braiding_operators(gamma0, gamma1)
    b12 = braiding_operators(gamma1, gamma2)
    b23 = braiding_operators(gamma2, gamma3)

        
    # Check if they are unitary
    assert np.allclose(np.eye(4), b01 @ b01.conj().T), "b01 is not unitary"
    assert np.allclose(np.eye(4), b12 @ b12.conj().T), "b12 is not unitary"
    assert np.allclose(np.eye(4), b23 @ b23.conj().T), "b23 is not unitary"

    assert np.allclose(b01 @ gamma0 @ b01.conj().T, gamma1), "b01 does not braid gamma0 to gamma1"
    assert np.allclose(b01 @ gamma1 @ b01.conj().T, -gamma0), "b01 does not braid gamma1 to gamma0"
    assert np.allclose(b12 @ gamma1 @ b12.conj().T, gamma2), "b12 does not braid gamma1 to gamma2"
    assert np.allclose(b12 @ gamma2 @ b12.conj().T, -gamma1), "b12 does not braid gamma2 to gamma1"
    assert np.allclose(b23 @ gamma2 @ b23.conj().T, gamma3), "b23 does not braid gamma2 to gamma3"
    assert np.allclose(b23 @ gamma3 @ b23.conj().T, -gamma2), "b23 does not braid gamma3 to gamma2"

    print("All tests passed!")

test_braiding_ops()
# Out:
# All tests passed!

# %% [markdown]
# ### Braiding operators in $\ket{+-}$, $\ket{-+}$ basis

# %%
# """ Express B in the \ket{+-}, \ket{+-} basis"""
ket_pm = np.array([0, 1, 0, 0])
ket_mp = np.array([0, 0, 1, 0])

def project_to_odd_subspace(B):
    # Basis vectors for |+-⟩ and |-+⟩    
    return np.array([
        [ket_pm.conj() @ B @ ket_pm, ket_pm.conj() @ B @ ket_mp],
        [ket_mp.conj() @ B @ ket_pm, ket_mp.conj() @ B @ ket_mp]
    ])


def test_projected_braiding_ops():
    #Check if  X = B²_12 = B²_03 / Y = B²_02 = B²_13 / Z = B²_01 = B²_23
    gamma0, gamma1, gamma2, gamma3 = majorana_operators()
    # X
    b12 = braiding_operators(gamma1, gamma2)
    b03 = braiding_operators(gamma0, gamma3)
    # Y
    b02 = braiding_operators(gamma0, gamma2)
    b13 = braiding_operators(gamma1, gamma3)
    # Z
    b01 = braiding_operators(gamma0, gamma1)
    b23 = braiding_operators(gamma2, gamma3)




    b12_odd = project_to_odd_subspace(b12)
    b03_odd = project_to_odd_subspace(b03)

    b02_odd = project_to_odd_subspace(b02)
    b13_odd = project_to_odd_subspace(b13)

    b01_odd = project_to_odd_subspace(b01)
    b23_odd = project_to_odd_subspace(b23)

    #square
    b12_odd_sq = b12_odd @ b12_odd
    b03_odd_sq = b03_odd @ b03_odd
    b02_odd_sq = b02_odd @ b02_odd
    b13_odd_sq = b13_odd @ b13_odd
    b01_odd_sq = b01_odd @ b01_odd
    b23_odd_sq = b23_odd @ b23_odd

    assert np.allclose(b12_odd_sq, X), "B²_12 is not X"
    assert np.allclose(b03_odd_sq, -X), "B²_03 is not -X"
    assert np.allclose(b02_odd_sq, -Y), "B²_02 is not -Y"
    assert np.allclose(b13_odd_sq, -Y), "B²_13 is not -Y"
    assert np.allclose(b01_odd_sq, Z), "B²_01 is not Z"
    assert np.allclose(b23_odd_sq, -Z), "B²_23 is not -Z"
    assert np.allclose(b01_odd@b12_odd@b01_odd,np.exp(1j*np.pi/4)*Hadamard), "B_01 B_12 B_01 is not exp(iπ/4) Hadamard"

    print("All tests passed!")
    print("Projected braiding operators:")
    print("B²_12 ∼ X")
    print("B²_03 ∼ -X")
    print("B²_02 ∼ -Y")
    print("B²_13 ∼ -Y")
    print("B²_01 ∼ Z")
    print("B²_23 ∼ -Z")
    print("B_01 B_12 B_01 ∼ Hadamard")
test_projected_braiding_ops()
# Out:
# [[ 1.5+0.5j  0. +0.j   0. +0.j   0.5-0.5j]
#  [ 0. +0.j   1.5+0.5j -0.5+0.5j  0. +0.j ]
#  [ 0. +0.j  -0.5+0.5j  0.5+1.5j  0. +0.j ]
#  [ 0.5-0.5j  0. +0.j   0. +0.j   0.5+1.5j]]
# All tests passed!
# Projected braiding operators:
# B²_12 ∼ X
# B²_03 ∼ -X
# B²_02 ∼ -Y
# B²_13 ∼ -Y
# B²_01 ∼ Z
# B²_23 ∼ -Z
# B_01 B_12 B_01 ∼ Hadamard

# %% [markdown]
# ## c) Jordan-Wigner transform
#
# While we have a map between Majorana operators and Pauli operators acting on a subspace of a specific parity, we need to create yet another map in order to look at the braiding protocol. We saw how four Majoranas can make a qubit. In the braiding protocol, an additional pair of Majoranas will be used to make an exchange. In the braiding protocol, an additional pair of Majoranas will be used to make an exchange. The braiding protocol therefore needs six Majoranas to work. Four to make a qubit, and two extra auxiliary Majoranas to make the braid.
#
# The braiding protocol in [C. W. J. Beenakker] is expressed in terms of four Majoranas. One pair is "half" the qubit and one qubit is the auxiliary ones. To interret the result in terms of a qubit, an additional pair must be added. See [A. Tsintzis, R. S. Souto, K. Flensberg, J. Danon, and M. Leijnse] to see the protocol with all six Majoranas.
#
# To implement the Hamiltonian numerically, we should map the fermions to Pauli operators and tensor products of those. We already did so, but that was only mapping the operators in a specific parity sector. Now we want to be more general and express it in the full Hilbert space, in a version which is simple to implement numerically.
#
# The general form that the Hamiltonian takes during the braiding protocol is
# $$
# H(t) = ∑_{j=1}^{3} Δ_j i(t) γ_0γ_j
# $$
# Write down the representation of the Majorana operators in terms of tensor products of local Pauli
# or spin operators.

# %%
def tensor_product(arrays):
    """
    Computes the tensor product of a list of arrays
    """
    result = arrays[0]
    for array in arrays[1:]:
        result = np.kron(result, array)
    return result


def creation_operator(j:int, N:int) -> np.ndarray:
    """
    Returns the creation operator for a particle at site j for a N-site system
    """
    operators = [I] * N

    z_op = operators.copy()
    for i in range(j):
        z_op[i] = Z
    
    z_op = tensor_product(z_op)
    x_op = operators.copy()
    x_op[j] = X
    x_op = tensor_product(x_op)
    y_op = operators.copy()
    y_op[j] = Y
    y_op = tensor_product(y_op)
    return 0.5 * z_op @ (x_op + 1j*y_op)


def annihilation_operator(j:int, N:int) -> np.ndarray:
    """
    Returns the annihilation operator for a particle at site j for a N-site system
    """
    operators = [I] * N
    z_op = operators.copy()
    for i in range(j):
        z_op[i] = Z
    
    z_op = tensor_product(z_op)
    x_op = operators.copy()
    x_op[j] = X
    x_op = tensor_product(x_op)
    y_op = operators.copy()
    y_op[j] = Y
    y_op = tensor_product(y_op)
    return 0.5 * z_op @ (x_op - 1j*y_op)


def majorana_ops(j:int, N:int) -> np.ndarray:
    """
    Returns the Majorana operators for a particle at site j for a N-site system
    Order (gamma_{2j-1}, gamma_{2j})
    """
    cj = annihilation_operator(j, N)
    cj_dagger = creation_operator(j, N)
    gamma1 = cj_dagger + cj
    gamma2 = 1j * (cj - cj_dagger)
    return gamma1, gamma2


def test_expected_majorana_ops():
    """
    Test the expected Majorana operators
    """
    g0,g1 = majorana_ops(0,3) ## 0 refers to c_1
    g2,g3 = majorana_ops(1,3) ## 1 refers to c_2
    g4,g5 = majorana_ops(2,3) ## 2 refers to c_3

    #Check anticommutation relations
    gammas = [g0,g1,g2,g3,g4,g5]
    for i in range(len(gammas)):
        for j in range(i+1, len(gammas)):
            assert np.allclose(gammas[i] @ gammas[j] + gammas[j] @ gammas[i], 0), f"gamma{i} and gamma{j} do not anticommute"

    assert np.allclose(tensor_product([X,I,I]), g0), "gamma0 does not match"
    assert np.allclose(tensor_product([Y,I,I]), g1), "gamma1 does not match"
    assert np.allclose(tensor_product([Z,X,I]), g2), "gamma2 does not match"
    assert np.allclose(tensor_product([Z,Y,I]), g3), "gamma3 does not match"
    assert np.allclose(tensor_product([Z,Z,X]), g4), "gamma4 does not match"
    assert np.allclose(tensor_product([Z,Z,Y]), g5), "gamma5 does not match"

    print("All tests passed!")

test_expected_majorana_ops()
# Out:
# All tests passed!

# %% [markdown]
# ## d) Implement the Hamiltonian numerically
# With the operators expressed as Pauli operators, they can be implemented numerically by a tensor product.
#
# We also need to express the parameters $Δ_j(t)$ as a function of time. One suggestion is to parameterize it using the following parameters.
#  - $Δ_{\max}$ is a large value that the coupling takes on in those steps of the protocol where it is turned on.
#  - $Δ_{\min}$ is the value it takes when it switches off (in an ideal experiment this is zero)
#  - $s$ some parameter that determines how fast one changes from $Δ_{\min}$ to $Δ_{\max}$. The particular shape of the step is not that important, but the steepness should be tunable.
#  - $T$ is the total time of the protocol
#
# With $H(t)$ implemented, study how the energy spectrum evolves during the protocol. Does it match expectations?

# %%
@njit
def delta_pulse(t, T_peak, width, s, Delta_max, Delta_min):
    """
    Improved smooth delta pulse with controllable width and steepness
    """
    # Calculate rise and fall times
    T_start = T_peak - width/2
    T_end = T_peak + width/2
    
    # Smooth step functions
    rise = 1/(1 + np.exp(-s*(t - T_start)))
    fall = 1/(1 + np.exp(s*(t - T_end)))
    
    return Delta_min + (Delta_max - Delta_min) * rise * fall

@njit
def build_hamiltonian(t, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3):
    """
    Constructs the time-dependent Hamiltonian H(t) = Σ Δ_j(t) iγ₀γ_j
    """
    
    # Time-dependent couplings
    Δ3 = delta_pulse(t, 0, width, s, Delta_max, Delta_min) + delta_pulse(t, T_total, width, s, Delta_max, Delta_min)
    Δ1 = delta_pulse(t, T_total/3, width, s, Delta_max, Delta_min)
    Δ2 = delta_pulse(t, 2*T_total/3, width, s, Delta_max, Delta_min)
    # Δ1 += delta_pulse(t, T_total, width, s, Delta_max, Delta_min)


    # Construct Hamiltonian terms
    H = (Δ1 * 1j * g0 @ g1 + 
         Δ2 * 1j * g0 @ g2 + 
         Δ3 * 1j * g0 @ g3)
    
    return H, (Δ1, Δ2, Δ3)

def analyze_spectrum(T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3, n_points=1000):
    times = np.linspace(0, T_total, n_points)
    energies = np.zeros((n_points, 4))  # Store all 4 eigenvalues
    couplings = np.zeros((n_points, 3))  # Store Δ1, Δ2, Δ3
    
    for i, t in enumerate(times):
        H, couplings[i] = build_hamiltonian(t, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3)
        
        e_vals = np.linalg.eigvalsh(H)
        energies[i] = e_vals
        # couplings[i] = np.array([Δ1, Δ2, Δ3])
    
    return times, energies, couplings

def plot_results(times, energies, couplings):
    plt.figure(figsize=(12, 8))
    
    # Plot energy spectrum
    plt.subplot(2, 1, 1)
    for i in range(4):
        plt.plot(times, energies[:, i], label=f'E{i}')
    plt.ylabel('Energy')
    plt.title('Energy Spectrum Evolution')
    plt.legend()
    
    # Plot couplings
    plt.subplot(2, 1, 2)
    labels = ['Δ₁(t)', 'Δ₂(t)', 'Δ₃(t)']
    linestyles = ['-', '-', '--']
    for i in range(3):
        plt.plot(times, couplings[:, i], label=labels[i], linestyle=linestyles[i])
    # for i in range(3):
    #     plt.plot(times, couplings[:, i], label=labels[i])
    plt.xlabel('Time')
    plt.ylabel('Coupling Strength')
    plt.title('Time-Dependent Couplings')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Get Majorana operators
g0, g1 = majorana_ops(0, 2)  # γ₀, γ₁
g2, g3 = majorana_ops(1, 2)  # γ₂, γ₃

T_total = 1.0
Delta_max = 1.0
Delta_min = 0.0
s = 50.0
width = T_total/3
# Parameters
params = {
    'T_total': T_total,
    'Delta_max': Delta_max,
    'Delta_min': Delta_min,
    's': s,
    'width': width,
    'g0': g0,
    'g1': g1,
    'g2': g2,
    'g3': g3,
    'n_points': 1000
}

# Run analysis
times, energies, couplings = analyze_spectrum(**params)

# Visualize
plot_results(times, energies, couplings)

# %% [markdown]
# ## e) Implement braiding protocol
# Now we are readu to solve the Schrodinger equation
# $$
# \frac{∂}{∂t} \ket{ ψ_t} = -i H_t \ket{ψ_t}
# $$
# The simplest way to do so is to approximate
# $$
# dt \frac{∂ }{∂t} \ket{ψ_t} ≈ \ket{ψ_{t+dt}} - \ket{ψ_t}
# $$
# and express the state at $t+dt$ in terms of the state at $t$. Then given an inital state, take short steps until reaching the final time $T$. The numerical error can be monitored by looking at the norm of the state, i.e. $\bra{ψ_t} \ket{ψ_t}$. How much this deviates from 1 gives a measure of how accurate the solution is.
#  - Find parameters so that the protocol succeeds and implements the desired exchange gate
#  - Measure parities during the protocol. Do they behave as expected?

# %%
from scipy.linalg import expm


# @njit
def evolve_wavefunction(psi0 ,T_total, Delta_max, Delta_min, s, width,g0,g1,g2,g3, n_steps=1000):
    dt = T_total / n_steps
    times = np.linspace(0, T_total, n_steps)
    psi = np.zeros((n_steps, 4), dtype=np.complex128)
    psi[0] = psi0

    couplings = np.zeros((n_steps, 3))  # Store Δ1, Δ2, Δ3

    norms = np.zeros(n_steps)
    norms[0] = np.linalg.norm(psi[0])


    evals = np.zeros((n_steps, 4))  # Store all 4 eigenvalues

    parities_mode1 = np.zeros(n_steps,dtype=np.complex128)
    parities_mode2 = np.zeros(n_steps,dtype=np.complex128)
    parities_mode3 = np.zeros(n_steps,dtype=np.complex128)

    for i in range(1, n_steps):
        H, (Δ1, Δ2, Δ3) = build_hamiltonian(times[i], T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3)
        e_vals = np.linalg.eigvalsh(H)
        evals[i] = e_vals
        psi[i] = expm(-1j * H * dt)  @ psi[i-1] #        psi[i] = expm(-1j * H * dt)  @ psi[i-1] #

        norm = np.linalg.norm(psi[i]) 
        psi[i] /= norm  # Normalize the wavefunction
        norms[i] = norm
        couplings[i] = np.array([Δ1, Δ2, Δ3])

        parities_mode1[i] = np.vdot(psi[i], (1j*g0@g1)@psi[i])
        parities_mode2[i] = np.vdot(psi[i], (1j*g1@g2)@psi[i])
        parities_mode3[i] = np.vdot(psi[i], (1j*g0@g3)@psi[i])

    couplings[0] = couplings[1]
    parities_mode1[0] = parities_mode1[1]
    parities_mode2[0] = parities_mode2[1]
    parities_mode3[0] = parities_mode3[1]

    parities = np.array([parities_mode1, parities_mode2, parities_mode3])

    return times, psi, norms, couplings, parities

def plot_evolution(times, psi, norms, couplings,parities):
    plt.figure(figsize=(12, 12))
    
    # Plot wavefunction probabilities
    plt.subplot(3, 1, 1)
    plt.plot(times, np.abs(psi[:, 0])**2, label='|00⟩')
    plt.plot(times, np.abs(psi[:, 1])**2, label='|01⟩')
    plt.plot(times, np.abs(psi[:, 2])**2, label='|10⟩')
    plt.plot(times, np.abs(psi[:, 3])**2, label='|11⟩')
    # plt.xlabel('Time')
    plt.ylabel('Probability')
    plt.title('Wavefunction Probabilities')
    plt.legend()
    
    # Plot norm
    plt.subplot(3, 1, 2)
    plt.plot(times, norms)
    plt.axhline(1, color='r', linestyle='--', label='Norm = 1')
    # plt.xlabel('Time')
    plt.ylabel('Norm')
    plt.ylim(-0.1, 1.2)
    plt.title('Norm of the Wavefunction')
    plt.legend()
    
    # Plot couplings
    plt.subplot(3, 1, 3)
    labels = ['Δ₁(t)', 'Δ₂(t)', 'Δ₃(t)']
    linestyles = ['-', '-', '--']
    for i in range(3):
        plt.plot(times, couplings[:, i], label=labels[i], linestyle=linestyles[i])
    plt.xlabel('Time')
    plt.ylabel('Coupling Strength')
    plt.title('Time-Dependent Couplings')
    plt.legend()
    
    plt.tight_layout()
    plt.show()
     
    # plot parities
    plt.figure(figsize=(12, 6))
    plt.subplot(3,1,1)
    plt.plot(times, parities[0].real, label='Parity Mode 1')
    plt.ylabel('Parity Mode 1')
    
    plt.subplot(3,1,2)
    plt.plot(times, parities[1].real, label='Parity Mode 2')
    plt.ylabel('Parity Mode 2')

    plt.subplot(3,1,3)
    plt.plot(times, parities[2].real, label='Parity Mode 3')
    plt.ylabel('Parity Mode 3')
    plt.xlabel('Time')
    plt.tight_layout()
    plt.show()



g0, g1 = majorana_ops(0, 2)  # γ₀, γ₁
g2, g3 = majorana_ops(1, 2)  # γ₂, γ₃



T_total = 20.0
Delta_max = 1.0
Delta_min = 0.0
s = 5.0
width = T_total/3

psi0 = Delta_max * np.array([0,1j*(np.sqrt(3) - 1), -1j+1,0], dtype=np.complex128)  # Initial state |01⟩
psi0 /= np.linalg.norm(psi0)  # Normalize the initial state


# Parameters
params = {
    'T_total': T_total,
    'Delta_max': Delta_max,
    'Delta_min': Delta_min,
    's': s,
    'width': width,
    'g0': g0,
    'g1': g1,
    'g2': g2,
    'g3': g3,
    'n_points': 1000
}

times, psi, norms, couplings, parities = evolve_wavefunction(psi0, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3, n_steps=1000)
plot_evolution(times, psi, norms, couplings, parities)

# %% [markdown]
# ## d) Implement the Hamiltonian numerically -Restart

# %%
import numpy as np
from numba import njit
import matplotlib.pyplot as plt

@njit
def delta_pulse(t, T_peak, width, s, Delta_max, Delta_min):
    """
    Improved smooth delta pulse with controllable width and steepness
    """
    # Calculate rise and fall times
    T_start = T_peak - width/2
    T_end = T_peak + width/2
    
    # Smooth step functions
    rise = 1/(1 + np.exp(-s*(t - T_start)))
    fall = 1/(1 + np.exp(s*(t - T_end)))
    
    return Delta_min + (Delta_max - Delta_min) * rise * fall

@njit
def build_hamiltonian(t, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3):
    """
    Constructs the time-dependent Hamiltonian H(t) = Σ Δ_j(t) iγ₀γ_j
    """
    
    # Time-dependent couplings
    Δ1 = delta_pulse(t, T_total/4, width, s, Delta_max, Delta_min)
    Δ2 = delta_pulse(t, T_total/2, width, s, Delta_max, Delta_min)
    Δ3 = delta_pulse(t, 3*T_total/4, width, s, Delta_max, Delta_min)


    # Construct Hamiltonian terms
    H = (Δ1 * 1j * g0 @ g1 + 
         Δ2 * 1j * g0 @ g2 + 
         Δ3 * 1j * g0 @ g3)
    
    return H, (Δ1, Δ2, Δ3)

def analyze_spectrum(T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3, n_points=1000):
    times = np.linspace(0, T_total, n_points)
    energies = np.zeros((n_points, 4))  # Store all 4 eigenvalues
    couplings = np.zeros((n_points, 3))  # Store Δ1, Δ2, Δ3
    
    for i, t in enumerate(times):
        H, couplings[i] = build_hamiltonian(t, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3)
        
        e_vals = np.linalg.eigvalsh(H)
        energies[i] = e_vals
        # couplings[i] = np.array([Δ1, Δ2, Δ3])
    
    return times, energies, couplings

def plot_results(times, energies, couplings):
    plt.figure(figsize=(12, 8))
    
    # Plot energy spectrum
    plt.subplot(2, 1, 1)
    for i in range(4):
        plt.plot(times, energies[:, i], label=f'E{i}')
    plt.ylabel('Energy')
    plt.title('Energy Spectrum Evolution')
    plt.legend()
    
    # Plot couplings
    plt.subplot(2, 1, 2)
    labels = ['Δ₁(t)', 'Δ₂(t)', 'Δ₃(t)']
    for i in range(3):
        plt.plot(times, couplings[:, i], label=labels[i])
    plt.xlabel('Time')
    plt.ylabel('Coupling Strength')
    plt.title('Time-Dependent Couplings')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Get Majorana operators
g0, g1 = majorana_ops(0, 2)  # γ₀, γ₁
g2, g3 = majorana_ops(1, 2)  # γ₂, γ₃

# Parameters
params = {
    'T_total': 20.0,
    'Delta_max': 10.0,
    'Delta_min': 0.1,
    's': 5.0,
    'width': 4.0,
    'g0': g0,
    'g1': g1,
    'g2': g2,
    'g3': g3,
    'n_points': 1000
}

# Run analysis
times, energies, couplings = analyze_spectrum(**params)

# Visualize
plot_results(times, energies, couplings)

# %% [markdown]
# ## e) Implement braiding protocol -Restart

# %%
from scipy.linalg import expm
@njit
def fidelity(psi, phi):
    """
    Calculate the fidelity between two wavefunctions
    """
    return np.abs(np.vdot(psi, phi))**2

@njit(debug=True)
def compute_gradient(psi, dt):
    n = psi.shape[0]
    grad = np.zeros_like(psi, dtype=np.complex128)
    for i in range(0, n - 1):
        grad[i] = (psi[i + 1] - psi[i]) / dt
    grad[-1] = grad[-2]  
    return grad

@njit(debug=True)
def berry_connection(psi, dt):
    dpsi_dt = compute_gradient(psi, dt)
    A_t = np.zeros(psi.shape[0], dtype=np.complex128)
    for i in range(psi.shape[0]):
        A_t[i] = -1j * np.dot(np.conj(psi[i]), dpsi_dt[i])
    return A_t

@njit(debug=True)
def berry_phase(psi, dt):
    A_t = berry_connection(psi, dt)
    return np.cumsum(A_t) * dt


    # phase = np.zeros(psi.shape[0], dtype=np.complex128)
    # for i in range(len(A_t)):
    #     phase[i] = 






# @njit
def evolve_wavefunction(psi0, target ,T_total, Delta_max, Delta_min, s, width,g0,g1,g2,g3, n_steps=1000):
    dt = T_total / n_steps
    times = np.linspace(0, T_total, n_steps)
    psi = np.zeros((n_steps, 4), dtype=np.complex128)
    psi[0] = psi0

    couplings = np.zeros((n_steps, 3))  # Store Δ1, Δ2, Δ3

    norms = np.zeros(n_steps)
    norms[0] = np.linalg.norm(psi[0])

    fidel = np.zeros(n_steps)
    fidel[0] = np.abs(np.vdot(psi[0], target))**2

    berryphase = np.zeros(n_steps, dtype=np.complex128)

    evals = np.zeros((n_steps, 4))  # Store all 4 eigenvalues

    for i in range(1, n_steps):
        H, (Δ1, Δ2, Δ3) = build_hamiltonian(times[i], T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3)
        e_vals = np.linalg.eigvalsh(H)
        evals[i] = e_vals
        psi[i] = expm(-1j * H * dt)  @ psi[i-1] #psi[i-1] - 1j * H @ psi[i-1] * dt  #
        norm = np.linalg.norm(psi[i]) 
        # psi[i] /= norm  # Normalize the wavefunction
        norms[i] = norm
        couplings[i] = np.array([Δ1, Δ2, Δ3])
        fidel[i] = fidelity(psi[i], target)
    berryphase = berry_phase(psi[:i+1],dt)

    # berryphase = n_berry_phase(psi,dt)
    # b_phase = berry_phase(psi,dt)


    return times, psi, norms, couplings, fidel, berryphase

def plot_evolution(times, psi, norms, couplings, fidelity, berry_phase):
    plt.figure(figsize=(12, 12))
    
    # Plot wavefunction probabilities
    plt.subplot(3, 1, 1)
    plt.plot(times, np.abs(psi[:, 0])**2, label='|00⟩')
    plt.plot(times, np.abs(psi[:, 1])**2, label='|01⟩')
    plt.plot(times, np.abs(psi[:, 2])**2, label='|10⟩')
    plt.plot(times, np.abs(psi[:, 3])**2, label='|11⟩')
    # plt.xlabel('Time')
    plt.ylabel('Probability')
    plt.title('Wavefunction Probabilities')
    plt.legend()
    
    # Plot norm
    plt.subplot(3, 1, 2)
    plt.plot(times, norms)
    plt.axhline(1, color='r', linestyle='--', label='Norm = 1')
    # plt.xlabel('Time')
    plt.ylabel('Norm')
    plt.ylim(-0.1, 1.2)
    plt.title('Norm of the Wavefunction')
    plt.legend()
    
    # Plot couplings
    plt.subplot(3, 1, 3)
    labels = ['Δ₁(t)', 'Δ₂(t)', 'Δ₃(t)']
    for i in range(3):
        plt.plot(times, couplings[:, i], label=labels[i])
    plt.xlabel('Time')
    plt.ylabel('Coupling Strength')
    plt.title('Time-Dependent Couplings')
    plt.legend()
    
    # Plot fidelityity
    fig, ax = plt.subplots(figsize=(12, 4))
    ax.plot(times, fidelity,label=f"Fidelity numeric: {fidelity[-1]:.2f}")
    ax.set_xlabel('Time', fontsize=12)
    ax.set_ylabel('Fidelity', fontsize=12)
    ax.set_title('Fidelity of the Wavefunction', fontsize=12)
    ax.axhline(1, color='r', linestyle='--', label='Fidelity = 1')
    ax.legend()
    plt.show()
    # Plot Berry phase

    plt.figure(figsize=(12, 6))
    plt.plot(times, berry_phase.real, label='Total Berry Phase') 
    plt.xlabel('Time', fontsize=12)    
    plt.axhline(berry_phase[-1].real, color='r', linestyle='--', label=f'Berry Phase = {berry_phase[-1].real:.2f}π')
    plt.ylabel('Berry Phase', fontsize=12)
    plt.title('Berry Phase of the Wavefunction', fontsize=12)
    plt.legend()
    plt.show()




g0, g1 = majorana_ops(0, 2)  # γ₀, γ₁
g2, g3 = majorana_ops(1, 2)  # γ₂, γ₃
b01 = braiding_operators(g0, g1)
b02 = braiding_operators(g0, g2)
b03 = braiding_operators(g0, g3)
b12 = braiding_operators(g1, g2)


psi0 = np.array([0, 1, 0, 0], dtype=np.complex128)  # Initial state |01⟩

controll_braid = b12 # = i(g0g1 + g0g2 + g0g3)
target = controll_braid @ psi0
target /= np.linalg.norm(target)

params = {
    'T_total': 20.0,
    'Delta_max': 10.0,
    'Delta_min': 0.001,
    's': 5.0,
    'width': 5.0,
    'g0': g0,
    'g1': g1,
    'g2': g2,
    'g3': g3,
    'n_steps': 5000
}

times, psi, norms, couplings, fidel, berry_phase  = evolve_wavefunction(psi0, target, **params)

plot_evolution(times, psi, norms, couplings, fidel, berry_phase)

for b in berry_phase:
    print(b)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 187
#     172 target /= np.linalg.norm(target)
#     174 params = {
#     175     'T_total': 20.0,
#     176     'Delta_max': 10.0,
#    (...)
#     184     'n_steps': 5000
#     185 }
# --> 187 times, psi, norms, couplings, fidel, berry_phase  = evolve_wavefunction(psi0, target, **params)
#     189 plot_evolution(times, psi, norms, couplings, fidel, berry_phase)
#     191 for b in berry_phase:
#
# Cell In[26], line 95, in evolve_wavefunction(psi0, target, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3, n_steps)
#      93     couplings[i] = np.array([Δ1, Δ2, Δ3])
#      94     fidel[i] = fidelity(psi[i], target)
# ---> 95 berryphase = berry_phase(psi[:i+1],dt)
#      97 # berryphase = n_berry_phase(psi,dt)
#      98 # b_phase = berry_phase(psi,dt)
#     101 return times, psi, norms, couplings, fidel, berryphase
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:376, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     374 return_val = None
#     375 try:
# --> 376     return_val = self.compile(tuple(argtypes))
#     377 except errors.ForceLiteralArg as e:
#     378     # Received request for compiler re-entry with the list of arguments
#     379     # indicated by e.requested_args.
#     380     # First, check if any of these args are already Literal-ized
#     381     already_lit_pos = [i for i in e.requested_args
#     382                        if isinstance(args[i], types.Literal)]
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:904, in Dispatcher.compile(self, sig)
#     902 with ev.trigger_event("numba:compile", data=ev_details):
#     903     try:
# --> 904         cres = self._compiler.compile(args, return_type)
#     905     except errors.ForceLiteralArg as e:
#     906         def folded(args, kws):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)
#     735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     106 """
#     107 Type inference and legalization
#     108 """
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#     121     # save errors in case of partial typing
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      91     infer.build_constraint()
#      92     # return errors in case of partial typing
# ---> 93     errs = infer.propagate(raise_errors=raise_errors)
#      94     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      96 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1066, in TypeInferer.propagate(self, raise_errors)
#    1063 oldtoken = newtoken
#    1064 # Errors can appear when the type set is incomplete; only
#    1065 # raise them when there is no progress anymore.
# -> 1066 errors = self.constraints.propagate(self)
#    1067 newtoken = self.get_state_token()
#    1068 self.debug.propagate_finished()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:566, in CallConstraint.__call__(self, typeinfer)
#     564     fnty = typevars[self.func].getone()
#     565 with new_error_context("resolving callee type: {0}", fnty):
# --> 566     self.resolve(typeinfer, typevars, fnty)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:589, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     587     fnty = fnty.instance_type
#     588 try:
# --> 589     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     590 except ForceLiteralArg as e:
#     591     # Adjust for bound methods
#     592     folding_args = ((fnty.this,) + tuple(self.args)
#     593                     if isinstance(fnty, types.BoundFunction)
#     594                     else self.args)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1560, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1557     return sig
#    1558 else:
#    1559     # Normal non-recursive call
# -> 1560     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/context.py:195, in BaseContext.resolve_function_type(self, func, args, kws)
#     193 # Prefer user definition first
#     194 try:
# --> 195     res = self._resolve_user_function_type(func, args, kws)
#     196 except errors.TypingError as e:
#     197     # Capture any typing error
#     198     last_exception = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/context.py:247, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     243         return self.resolve_function_type(func_type, args, kws)
#     245 if isinstance(func, types.Callable):
#     246     # XXX fold this into the __call__ attribute logic?
# --> 247     return func.get_call_type(self, args, kws)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:538, in Dispatcher.get_call_type(self, context, args, kws)
#     531 def get_call_type(self, context, args, kws):
#     532     """
#     533     Resolve a call to this dispatcher using the given argument types.
#     534     A signature returned and it is ensured that a compiled specialization
#     535     is available for it.
#     536     """
#     537     template, pysig, args, kws = \
# --> 538         self.dispatcher.get_call_template(args, kws)
#     539     sig = template(context).apply(args, kws)
#     540     if sig:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:904, in Dispatcher.compile(self, sig)
#     902 with ev.trigger_event("numba:compile", data=ev_details):
#     903     try:
# --> 904         cres = self._compiler.compile(args, return_type)
#     905     except errors.ForceLiteralArg as e:
#     906         def folded(args, kws):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)
#     735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     106 """
#     107 Type inference and legalization
#     108 """
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#     121     # save errors in case of partial typing
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      91     infer.build_constraint()
#      92     # return errors in case of partial typing
# ---> 93     errs = infer.propagate(raise_errors=raise_errors)
#      94     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      96 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1066, in TypeInferer.propagate(self, raise_errors)
#    1063 oldtoken = newtoken
#    1064 # Errors can appear when the type set is incomplete; only
#    1065 # raise them when there is no progress anymore.
# -> 1066 errors = self.constraints.propagate(self)
#    1067 newtoken = self.get_state_token()
#    1068 self.debug.propagate_finished()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:566, in CallConstraint.__call__(self, typeinfer)
#     564     fnty = typevars[self.func].getone()
#     565 with new_error_context("resolving callee type: {0}", fnty):
# --> 566     self.resolve(typeinfer, typevars, fnty)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:589, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     587     fnty = fnty.instance_type
#     588 try:
# --> 589     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     590 except ForceLiteralArg as e:
#     591     # Adjust for bound methods
#     592     folding_args = ((fnty.this,) + tuple(self.args)
#     593                     if isinstance(fnty, types.BoundFunction)
#     594                     else self.args)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1560, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1557     return sig
#    1558 else:
#    1559     # Normal non-recursive call
# -> 1560     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/context.py:195, in BaseContext.resolve_function_type(self, func, args, kws)
#     193 # Prefer user definition first
#     194 try:
# --> 195     res = self._resolve_user_function_type(func, args, kws)
#     196 except errors.TypingError as e:
#     197     # Capture any typing error
#     198     last_exception = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/context.py:247, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     243         return self.resolve_function_type(func_type, args, kws)
#     245 if isinstance(func, types.Callable):
#     246     # XXX fold this into the __call__ attribute logic?
# --> 247     return func.get_call_type(self, args, kws)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:538, in Dispatcher.get_call_type(self, context, args, kws)
#     531 def get_call_type(self, context, args, kws):
#     532     """
#     533     Resolve a call to this dispatcher using the given argument types.
#     534     A signature returned and it is ensured that a compiled specialization
#     535     is available for it.
#     536     """
#     537     template, pysig, args, kws = \
# --> 538         self.dispatcher.get_call_template(args, kws)
#     539     sig = template(context).apply(args, kws)
#     540     if sig:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:904, in Dispatcher.compile(self, sig)
#     902 with ev.trigger_event("numba:compile", data=ev_details):
#     903     try:
# --> 904         cres = self._compiler.compile(args, return_type)
#     905     except errors.ForceLiteralArg as e:
#     906         def folded(args, kws):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)
#     735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:468, in BaseNativeLowering.run_pass(self, state)
#     465 with targetctx.push_code_library(library):
#     466     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     467                                 metadata=metadata)
# --> 468     lower.lower()
#     469     if not flags.no_cpython_wrapper:
#     470         lower.create_cpython_wrapper(flags.release_gil)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/lowering.py:193, in BaseLower.lower(self)
#     191 if self.generator_info is None:
#     192     self.genlower = None
# --> 193     self.lower_normal_function(self.fndesc)
#     194 else:
#     195     self.genlower = self.GeneratorLower(self)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/lowering.py:232, in BaseLower.lower_normal_function(self, fndesc)
#     230 # Init argument values
#     231 self.extract_function_arguments()
# --> 232 entry_block_tail = self.lower_function_body()
#     234 # Close tail of entry block, do not emit debug metadata else the
#     235 # unconditional jump gets associated with the metadata from the function
#     236 # body end.
#     237 with debuginfo.suspend_emission(self.builder):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/lowering.py:262, in BaseLower.lower_function_body(self)
#     260     self.builder.position_at_end(bb)
#     261     self.debug_print(f"# lower block: {offset}")
# --> 262     self.lower_block(block)
#     263 self.post_lower()
#     264 return entry_block_tail
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/lowering.py:276, in BaseLower.lower_block(self, block)
#     273     defaulterrcls = partial(LoweringError, loc=self.loc)
#     274     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     275                            loc=self.loc, errcls_=defaulterrcls):
# --> 276         self.lower_inst(inst)
#     277 self.post_block(block)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/lowering.py:529, in Lower.lower_inst(self, inst)
#     527     signature = self.fndesc.calltypes[inst]
#     528     assert signature is not None
# --> 529     return self.lower_setitem(inst.target, inst.index, inst.value,
#     530                               signature)
#     532 elif isinstance(inst, ir.StoreMap):
#     533     signature = self.fndesc.calltypes[inst]
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/lowering.py:624, in Lower.lower_setitem(self, target_var, index_var, value_var, signature)
#     619 index = self.context.cast(self.builder, index, indexty,
#     620                           signature.args[1])
#     621 value = self.context.cast(self.builder, value, valuety,
#     622                           signature.args[2])
# --> 624 return impl(self.builder, (target, index, value))
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/base.py:1190, in _wrap_impl.__call__(self, builder, args, loc)
#    1189 def __call__(self, builder, args, loc=None):
# -> 1190     res = self._imp(self._context, builder, self._sig, args, loc=loc)
#    1191     self._context.add_linking_libs(getattr(self, 'libs', ()))
#    1192     return res
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/base.py:1220, in _wrap_missing_loc.__call__.<locals>.wrapper(*args, **kwargs)
#    1218 def wrapper(*args, **kwargs):
#    1219     kwargs.pop('loc')     # drop unused loc
# -> 1220     return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/np/arrayobj.py:556, in setitem_array(context, builder, sig, args)
#     551     use_fancy_indexing = bool(shapes)
#     553 if use_fancy_indexing:
#     554     # Index describes a non-trivial view => use generic slice assignment
#     555     # (NOTE: this also handles scalar broadcasting)
# --> 556     return fancy_setslice(context, builder, sig, args,
#     557                           index_types, indices)
#     559 # Store source value the given location
#     560 val = context.cast(builder, val, valty, aryty.dtype)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/np/arrayobj.py:1719, in fancy_setslice(context, builder, sig, args, index_types, indices)
#    1715     shape_error = builder.or_(shape_error,
#    1716                               builder.icmp_signed('!=', u, v))
#    1718 with builder.if_then(shape_error, likely=False):
# -> 1719     raise_shape_mismatch_error(context, builder, src_shapes,
#    1720                                index_shape)
#    1722 # Check for array overlap
#    1723 src_start, src_end = get_array_memory_extents(context, builder, srcty,
#    1724                                               src, src_shapes,
#    1725                                               src_strides, src_data)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/np/arrayobj.py:1691, in fancy_setslice.<locals>.raise_shape_mismatch_error(context, builder, src_shapes, index_shape)
#    1687 fnty = context.typing_context.resolve_value_type(
#    1688     raise_with_shape_context)
#    1689 argtys = (types.UniTuple(types.int64, len(src_shapes)),
#    1690           types.UniTuple(types.int64, len(index_shape)))
# -> 1691 raise_sig = fnty.get_call_type(context.typing_context, argtys, {})
#    1692 func = context.get_function(fnty, raise_sig)
#    1693 func(builder, (context.make_tuple(builder, raise_sig.args[0],
#    1694                                   src_shapes),
#    1695                context.make_tuple(builder, raise_sig.args[1],
#    1696                                   index_shape)))
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if not isinstance(e, errors.NumbaError):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:621, in _OverloadFunctionTemplate.generic(self, args, kws)
#     615 """
#     616 Type the overloaded function by compiling the appropriate
#     617 implementation for the given args.
#     618 """
#     619 from numba.core.typed_passes import PreLowerStripPhis
# --> 621 disp, new_args = self._get_impl(args, kws)
#     622 if disp is None:
#     623     return
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:720, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     716 except KeyError:
#     717     # pass and try outside the scope so as to not have KeyError with a
#     718     # nested addition error in the case the _build_impl fails
#     719     pass
# --> 720 impl, args = self._build_impl(cache_key, args, kws)
#     721 return impl, args
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:824, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     822 # Make sure that the implementation can be fully compiled
#     823 disp_type = types.Dispatcher(disp)
# --> 824 disp_type.get_call_type(self.context, args, kws)
#     825 if cache_key is not None:
#     826     self._impl_cache[cache_key] = disp, args
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:538, in Dispatcher.get_call_type(self, context, args, kws)
#     531 def get_call_type(self, context, args, kws):
#     532     """
#     533     Resolve a call to this dispatcher using the given argument types.
#     534     A signature returned and it is ensured that a compiled specialization
#     535     is available for it.
#     536     """
#     537     template, pysig, args, kws = \
# --> 538         self.dispatcher.get_call_template(args, kws)
#     539     sig = template(context).apply(args, kws)
#     540     if sig:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:904, in Dispatcher.compile(self, sig)
#     902 with ev.trigger_event("numba:compile", data=ev_details):
#     903     try:
# --> 904         cres = self._compiler.compile(args, return_type)
#     905     except errors.ForceLiteralArg as e:
#     906         def folded(args, kws):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)
#     735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     106 """
#     107 Type inference and legalization
#     108 """
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#     121     # save errors in case of partial typing
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      91     infer.build_constraint()
#      92     # return errors in case of partial typing
# ---> 93     errs = infer.propagate(raise_errors=raise_errors)
#      94     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      96 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1066, in TypeInferer.propagate(self, raise_errors)
#    1063 oldtoken = newtoken
#    1064 # Errors can appear when the type set is incomplete; only
#    1065 # raise them when there is no progress anymore.
# -> 1066 errors = self.constraints.propagate(self)
#    1067 newtoken = self.get_state_token()
#    1068 self.debug.propagate_finished()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:566, in CallConstraint.__call__(self, typeinfer)
#     564     fnty = typevars[self.func].getone()
#     565 with new_error_context("resolving callee type: {0}", fnty):
# --> 566     self.resolve(typeinfer, typevars, fnty)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:589, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     587     fnty = fnty.instance_type
#     588 try:
# --> 589     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     590 except ForceLiteralArg as e:
#     591     # Adjust for bound methods
#     592     folding_args = ((fnty.this,) + tuple(self.args)
#     593                     if isinstance(fnty, types.BoundFunction)
#     594                     else self.args)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1560, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1557     return sig
#    1558 else:
#    1559     # Normal non-recursive call
# -> 1560     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/context.py:195, in BaseContext.resolve_function_type(self, func, args, kws)
#     193 # Prefer user definition first
#     194 try:
# --> 195     res = self._resolve_user_function_type(func, args, kws)
#     196 except errors.TypingError as e:
#     197     # Capture any typing error
#     198     last_exception = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/context.py:247, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     243         return self.resolve_function_type(func_type, args, kws)
#     245 if isinstance(func, types.Callable):
#     246     # XXX fold this into the __call__ attribute logic?
# --> 247     return func.get_call_type(self, args, kws)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if not isinstance(e, errors.NumbaError):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:621, in _OverloadFunctionTemplate.generic(self, args, kws)
#     615 """
#     616 Type the overloaded function by compiling the appropriate
#     617 implementation for the given args.
#     618 """
#     619 from numba.core.typed_passes import PreLowerStripPhis
# --> 621 disp, new_args = self._get_impl(args, kws)
#     622 if disp is None:
#     623     return
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:720, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     716 except KeyError:
#     717     # pass and try outside the scope so as to not have KeyError with a
#     718     # nested addition error in the case the _build_impl fails
#     719     pass
# --> 720 impl, args = self._build_impl(cache_key, args, kws)
#     721 return impl, args
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:824, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     822 # Make sure that the implementation can be fully compiled
#     823 disp_type = types.Dispatcher(disp)
# --> 824 disp_type.get_call_type(self.context, args, kws)
#     825 if cache_key is not None:
#     826     self._impl_cache[cache_key] = disp, args
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:538, in Dispatcher.get_call_type(self, context, args, kws)
#     531 def get_call_type(self, context, args, kws):
#     532     """
#     533     Resolve a call to this dispatcher using the given argument types.
#     534     A signature returned and it is ensured that a compiled specialization
#     535     is available for it.
#     536     """
#     537     template, pysig, args, kws = \
# --> 538         self.dispatcher.get_call_template(args, kws)
#     539     sig = template(context).apply(args, kws)
#     540     if sig:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:904, in Dispatcher.compile(self, sig)
#     902 with ev.trigger_event("numba:compile", data=ev_details):
#     903     try:
# --> 904         cres = self._compiler.compile(args, return_type)
#     905     except errors.ForceLiteralArg as e:
#     906         def folded(args, kws):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)
#     735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# ...
#     108 """
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#     121     # save errors in case of partial typing
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      91     infer.build_constraint()
#      92     # return errors in case of partial typing
# ---> 93     errs = infer.propagate(raise_errors=raise_errors)
#      94     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      96 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1066, in TypeInferer.propagate(self, raise_errors)
#    1063 oldtoken = newtoken
#    1064 # Errors can appear when the type set is incomplete; only
#    1065 # raise them when there is no progress anymore.
# -> 1066 errors = self.constraints.propagate(self)
#    1067 newtoken = self.get_state_token()
#    1068 self.debug.propagate_finished()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:566, in CallConstraint.__call__(self, typeinfer)
#     564     fnty = typevars[self.func].getone()
#     565 with new_error_context("resolving callee type: {0}", fnty):
# --> 566     self.resolve(typeinfer, typevars, fnty)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:589, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     587     fnty = fnty.instance_type
#     588 try:
# --> 589     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     590 except ForceLiteralArg as e:
#     591     # Adjust for bound methods
#     592     folding_args = ((fnty.this,) + tuple(self.args)
#     593                     if isinstance(fnty, types.BoundFunction)
#     594                     else self.args)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1560, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1557     return sig
#    1558 else:
#    1559     # Normal non-recursive call
# -> 1560     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/context.py:195, in BaseContext.resolve_function_type(self, func, args, kws)
#     193 # Prefer user definition first
#     194 try:
# --> 195     res = self._resolve_user_function_type(func, args, kws)
#     196 except errors.TypingError as e:
#     197     # Capture any typing error
#     198     last_exception = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/context.py:247, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     243         return self.resolve_function_type(func_type, args, kws)
#     245 if isinstance(func, types.Callable):
#     246     # XXX fold this into the __call__ attribute logic?
# --> 247     return func.get_call_type(self, args, kws)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:398, in BoundFunction.get_call_type(self, context, args, kws)
#     395 if uselit:
#     396     # Try with Literal
#     397     try:
# --> 398         out = template.apply(args, kws)
#     399     except Exception as exc:
#     400         if not isinstance(exc, errors.NumbaError):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:1140, in _OverloadMethodTemplate._resolve.<locals>.MethodTemplate.generic(_, args, kws)
#    1138 args = (typ,) + tuple(args)
#    1139 fnty = self._get_function_type(self.context, typ)
# -> 1140 sig = self._get_signature(self.context, fnty, args, kws)
#    1141 sig = sig.replace(pysig=utils.pysignature(self._overload_func))
#    1142 for template in fnty.templates:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:1085, in _OverloadAttributeTemplate._get_signature(cls, typingctx, fnty, args, kws)
#    1083 @classmethod
#    1084 def _get_signature(cls, typingctx, fnty, args, kws):
# -> 1085     sig = fnty.get_call_type(typingctx, args, kws)
#    1086     sig = sig.replace(pysig=utils.pysignature(cls._overload_func))
#    1087     return sig
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if not isinstance(e, errors.NumbaError):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:621, in _OverloadFunctionTemplate.generic(self, args, kws)
#     615 """
#     616 Type the overloaded function by compiling the appropriate
#     617 implementation for the given args.
#     618 """
#     619 from numba.core.typed_passes import PreLowerStripPhis
# --> 621 disp, new_args = self._get_impl(args, kws)
#     622 if disp is None:
#     623     return
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:720, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     716 except KeyError:
#     717     # pass and try outside the scope so as to not have KeyError with a
#     718     # nested addition error in the case the _build_impl fails
#     719     pass
# --> 720 impl, args = self._build_impl(cache_key, args, kws)
#     721 return impl, args
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typing/templates.py:824, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     822 # Make sure that the implementation can be fully compiled
#     823 disp_type = types.Dispatcher(disp)
# --> 824 disp_type.get_call_type(self.context, args, kws)
#     825 if cache_key is not None:
#     826     self._impl_cache[cache_key] = disp, args
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/types/functions.py:538, in Dispatcher.get_call_type(self, context, args, kws)
#     531 def get_call_type(self, context, args, kws):
#     532     """
#     533     Resolve a call to this dispatcher using the given argument types.
#     534     A signature returned and it is ensured that a compiled specialization
#     535     is available for it.
#     536     """
#     537     template, pysig, args, kws = \
# --> 538         self.dispatcher.get_call_template(args, kws)
#     539     sig = template(context).apply(args, kws)
#     540     if sig:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:904, in Dispatcher.compile(self, sig)
#     902 with ev.trigger_event("numba:compile", data=ev_details):
#     903     try:
# --> 904         cres = self._compiler.compile(args, return_type)
#     905     except errors.ForceLiteralArg as e:
#     906         def folded(args, kws):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)
#     735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/typed_passes.py:497, in BaseNativeLowering.run_pass(self, state)
#     491     state['cr'] = _LowerResult(fndesc, call_helper,
#     492                                cfunc=None, env=env)
#     493 else:
#     494     # Prepare for execution
#     495     # Insert native function for use by other jitted-functions.
#     496     # We also register its library to allow for inlining.
# --> 497     cfunc = targetctx.get_executable(library, fndesc, env)
#     498     targetctx.insert_user_function(cfunc, fndesc, [library])
#     499     state['cr'] = _LowerResult(fndesc, call_helper,
#     500                                cfunc=cfunc, env=env)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/cpu.py:239, in CPUContext.get_executable(self, library, fndesc, env)
#     226 """
#     227 Returns
#     228 -------
#    (...)
#     236     an execution environment (from _dynfunc)
#     237 """
#     238 # Code generation
# --> 239 fnptr = library.get_pointer_to_function(
#     240     fndesc.llvm_cpython_wrapper_name)
#     242 # Note: we avoid reusing the original docstring to avoid encoding
#     243 # issues on Python 2, see issue #1908
#     244 doc = "compiled wrapper for %r" % (fndesc.qualname,)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/codegen.py:997, in JITCodeLibrary.get_pointer_to_function(self, name)
#     983 def get_pointer_to_function(self, name):
#     984     """
#     985     Generate native code for function named *name* and return a pointer
#     986     to the start of the function (as an integer).
#    (...)
#     995         - non-zero if the symbol is defined.
#     996     """
# --> 997     self._ensure_finalized()
#     998     ee = self._codegen._engine
#     999     if not ee.is_symbol_defined(name):
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/codegen.py:567, in CodeLibrary._ensure_finalized(self)
#     565 def _ensure_finalized(self):
#     566     if not self._finalized:
# --> 567         self.finalize()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/codegen.py:772, in CPUCodeLibrary.finalize(self)
#     768 # Optimize the module after all dependences are linked in above,
#     769 # to allow for inlining.
#     770 self._optimize_final_module()
# --> 772 self._final_module.verify()
#     773 self._finalize_final_module()
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/llvmlite/binding/module.py:114, in ModuleRef.verify(self)
#     110 """
#     111 Verify the module IR's correctness.  RuntimeError is raised on error.
#     112 """
#     113 with ffi.OutputString() as outmsg:
# --> 114     if ffi.lib.LLVMPY_VerifyModule(self, outmsg):
#     115         raise RuntimeError(str(outmsg))
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/llvmlite/binding/ffi.py:197, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     195 def __call__(self, *args, **kwargs):
#     196     with self._lock:
# --> 197         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Later work?

# %%
def quantum_gate_braid_protocol(gate:str="X",N:int = 2, T:float = 20.0, dt:float = 0.01 ,delta_max:float = 100.0, delta_min:float = 0.1, s:float = 10.0):
    """Compute the braiding protocol for a given quantum gate.
    N fermions are used to create 2**N majorana operators.
    Then the right braiding operators are aquired for the given gate.
    Then the corresponding Hamiltonian is constructed.
    The Hamiltonian is then used to compute the time evolution of the system. 

    Args:
    gate (str): The quantum gate to be implemented. Options are "X", "Y", "Z", or "Hadamard".
    N (int): The number of fermions used to create the Majorana operators.
        - Minimum value is 2 (Later will be 3, 2 for the gate recreation and 1 for the readout)
    T (float): The total time for the braiding protocol.
    dt (float): The time step for the time evolution.
    delta_max (float): The maximum value of the delta function.
    delta_min (float): The minimum value of the delta function.
    s (float): The parameter s for the delta function.

    """

    # Create Majorana operators
    gammas = []
    for i in range(N):
        g1, g2 = majorana_ops(i, N)
        gammas.append(g1)
        gammas.append(g2)
    gammas = np.array(gammas)

    # Define the braiding operators
    gate_to_braids = {
        "X": [(1,2), (1,2)],
        "Y": [(0,2), (0,2)],
        "Z": [(0,1), (0,1)],
        "Hadamard": [(0,1), (1,2), (0,1)]
    }

    braids = gate_to_braids.get(gate)
    
    #Create braiding operators and the needed gamma operators
    braiding_ops = []
    braiding_gammas = []
    for braid in braids:
        i, j = braid
        b = braiding_operators(gammas[i], gammas[j])
        g = gammas[i] @ gammas[j]

        braiding_ops.append(b)
        braiding_gammas.append(g)

    def H_t(t:np.ndarray,T_braid:float,s:float,delta_max:float,delta_min:float) -> float:
        """
        Returns the Hamiltonian for a given time T and s
        """
        H = np.zeros((2**N, 2**N), dtype=complex)
        for b in range(len(braiding_ops)):
            #T_braid, time of braid, evenly spaced in the time interval
            T_braid = T/(len(braiding_ops) + 1 ) * (b+1)
            H += braiding_gammas[b] * delta(t, T_braid, s, delta_max, delta_min)
        return H


    
    H = H_t(0, T, delta_max, delta_min, s)

    # Find the eigenvalues and eigenvectors of the Hamiltonian
    e_vals, e_vecs = np.linalg.eigh(H)
    Psi = np.zeros((int(T/dt), 2**N), dtype=complex)
    Psi[0] = e_vecs[:, 0]  # Ground state

    # Norm of the wavefunction
    norms = np.zeros(int(T/dt))
    norms[0] = np.linalg.norm(Psi[0])


    # Time evolution
    time_array = np.linspace(0, T, int(T/dt))
    for i in range(1,len(time_array)):
        # Create the Hamiltonian at time t
        H = H_t(time_array[i], T, delta_max, delta_min, s)
        # Update the wavefunction
        Psi[i] = Psi[i-1] + 1j * H @ Psi[i-1] * dt
        # Normalize the wavefunction
        norm = np.linalg.norm(Psi[i])
        Psi[i] /= norm
        norms[i] = norm
    

    return Psi, norms, time_array
Psi, norms, times = quantum_gate_braid_protocol("Hadamard")  




plt.figure(figsize=(12, 6))
plt.plot(times, norms)
plt.xlabel('Time', fontsize=12)
plt.ylabel('Norm', fontsize=12)
plt.title('Norm of the wavefunction', fontsize=12)
plt.axhline(1, color='r', linestyle='--', label='Norm = 1')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.axhline(1, color='r', linestyle='--', label='Norm = 1')
plt.plot(times,np.abs(Psi[:,0]**2), label=f'⟨00|00⟩= {np.mean(np.abs(Psi[:,0])**2):.2f}')
plt.plot(times, np.abs(Psi[:,1])**2, label=f'⟨01|01⟩= {np.mean(np.abs(Psi[:,1])**2):.2f}')
plt.plot(times, np.abs(Psi[:,2])**2, label=f'⟨10|10⟩= {np.mean(np.abs(Psi[:,2])**2):.2f}')
plt.plot(times, np.abs(Psi[:,3])**2, label=f'⟨11|11⟩= {np.mean(np.abs(Psi[:,3])**2):.2f}')
plt.plot(times, np.linalg.norm(Psi,axis=1)**2, label=f'|psi|^2= {np.mean(np.linalg.norm(Psi,axis=1)**2):.1f}')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Probability', fontsize=12)
plt.ylim(-0.1, 1.2)
plt.title('Probability of the wavefunction', fontsize=12)
plt.legend( loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 88
#      84         norms[i] = norm
#      87     return Psi, norms, time_array
# ---> 88 Psi, norms, times = quantum_gate_braid_protocol("Hadamard")
#      93 plt.figure(figsize=(12, 6))
#      94 plt.plot(times, norms)
#
# Cell In[9], line 62, in quantum_gate_braid_protocol(gate, N, T, dt, delta_max, delta_min, s)
#      57         H += braiding_gammas[b] * delta(t, T_braid, s, delta_max, delta_min)
#      58     return H
# ---> 62 H = H_t(0, T, delta_max, delta_min, s)
#      64 # Find the eigenvalues and eigenvectors of the Hamiltonian
#      65 e_vals, e_vecs = np.linalg.eigh(H)
#
# Cell In[9], line 57, in quantum_gate_braid_protocol.<locals>.H_t(t, T_braid, s, delta_max, delta_min)
#      54 for b in range(len(braiding_ops)):
#      55     #T_braid, time of braid, evenly spaced in the time interval
#      56     T_braid = T/(len(braiding_ops) + 1 ) * (b+1)
# ---> 57     H += braiding_gammas[b] * delta(t, T_braid, s, delta_max, delta_min)
#      58 return H
#
# NameError: name 'delta' is not defined
