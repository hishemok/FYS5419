# %% [markdown]
# # Braiding project for Quantum Computation course

# %% [markdown]
# ## a) Qubits vs Fermions
#
# The usual model of quantum computation is expressed in terms of qubits and Pauli operators $X$ $Y$ and $Z$. A single fermionic mode is also a two-level system (either occupied or not), but is quite different from a qubit. Two key features are fermionic parity conservation and the anti-commutation relations.
#
# Parity conservation means that we can't make superpositions between states of even and odd fermionic numbers. Therefore, a single fermionic mode can't be used as a qubit. It is a two-level system, but we are not allowed to make superpostions between the two states.
#
# The anti-commutation relations imply that fermionic operators are non-local, which means they do not map cleanly to the local Pauli gates.
#
# Let's take system with two fermionic, $c_1$ and $c_2$. The Hilbert space is 4-dimensional, but because of parity conservation, we can consider the two subspaces of even and odd total parity separately. Let's take the odd parity subspace to be concrete. This is a two level system, spanned by the states $\ket{+ -}$ (left mode is unoccupied (even parity) and the right mode is occupied (odd parity)) and $\ket{ - +}$. We can write down the standard Pauli operators in this space, i.e $X = \begin{pmatrix} 0 &1\\1&0 \end{pmatrix}$.
#
#  - Express the Pauli operators in terms of the fermions $c_1$ and $c_2$.
#  - Define four hermitian Majorana operators $γ_0,γ_1,γ_2,γ_3$ with the mapping $c_k=\displaystyle \frac{γ_{2k-2} + iγ_{2k-1}}{2}$.
#  - What are the anti-commutation relations between the Majoranas?
#  - Express the Pauli operators in terms of Majorana operators.

# %% [markdown]
# ### Pauli gates in terms of fermions
# $c_i$ ammihilates a fermion in mode $i$ and $c_i^{†}$ creates a fermion in mode $i$.
#
# We know that the Pauli $X$ gate flips the bit.
# From this we can express it as:
# $$X = c_1^{†} c_2 + c_2^{†} c_1 $$
#
# The Pauli $Y$ gate does an imaginary bitflip
# $$ Y = -i(c_1^{†} c_2 - c_2^{†} c_1)$$
#
# And $Z$ changes the sign of the $\ket{1}$ and leaves $\ket{0}$ unchanged
# $$Z = c_1^{†}c_1 - c_2^{†} c_2$$
#
# ### Define four majorana operators
# $$c_1= \frac{γ_0 + iγ_1}{2} \quad c_1^{†}= \frac{γ_0 - iγ_1}{2} $$
# $$c_2= \frac{γ_2 + iγ_3}{2} \quad c_2^{†}= \frac{γ_2 - iγ_3}{2} $$
#
# ### The anti-commutation relations between Majoranas
# Hermitian: $γ_j = γ_j^{†}$
#
# Canonical anti-commutation: $\{γ_j,γ_k\}=2δ_{jk}$
#
# Meaning:
# $γ_j^{2}=1$ and
# $γ_j γ_k = -γ_k γ_j$ for $j≠ k$

# %% [markdown]
# ### Express Pauli operators in terms of Majorana Operators
# Firstly $X$
# $$
# X = c_1^{†} c_2 + c_2^{†} c_1 = \frac{γ_0 - iγ_1}{2} \frac{γ_2 + iγ_3}{2}  +  \frac{γ_2 - iγ_3}{2}\frac{γ_0 + iγ_1}{2}
# $$
# $$
# =\frac{1}{4} (γ_0γ_2 + iγ_0γ_3 - iγ_1γ_2 + γ_1γ_3 + γ_2γ_0 + iγ_2γ_1 -iγ_3γ_0 + γ_3γ_1)
# $$
# Using the anti-commutation rules
# $$
# =\frac{1}{4} ( iγ_0γ_3 - iγ_1γ_2  + iγ_2γ_1 -iγ_3γ_0 )
# $$
# $$
# =\frac{i}{2} ( γ_0γ_3 - γ_1γ_2 )
# $$
#
# From the odd parity subspace we have the total Parity operator $P_{tot}=i²γ_0γ_1γ_2γ_3=-I$. From this we can try to find a relation between $γ_0γ_3$ and $γ_1γ_2$.
# $$
# γ_0γ_1γ_2γ_3 = I\\
# γ_0γ_1γ_2γ_3 γ_3 = γ_3\\
# γ_0γ_1γ_2 = γ_3 \\
# γ_1γ_2γ_0γ_0 = γ_3γ_0\\
# γ_1γ_2=γ_3γ_0=-γ_0γ_3
# $$
# Thus $X$ becomes
# $$
# X = -iγ_1γ_2 \text{ or } X = iγ_0γ_3
# $$

# %% [markdown]
# Now for $Y$
#
# $$ Y = -i(c_1^{†} c_2 - c_2^{†} c_1) = -i (  \frac{γ_0 - iγ_1}{2} \frac{γ_2 + iγ_3}{2}  -  \frac{γ_2 - iγ_3}{2}\frac{γ_0 + iγ_1}{2} )
# $$
#
# $$
# = \frac{-i}{4} (γ_0γ_2 + iγ_0γ_3 - iγ_1γ_2 + γ_1γ_3 - γ_2γ_0 - iγ_2γ_1 +iγ_3γ_0 - γ_3γ_1)
# $$
# $$
# = \frac{-i}{2} (γ_0γ_2 + γ_1γ_3)
# $$
#
# $$
# Y = -i γ_0γ_2 \text{ or } Y = -i γ_1γ_3
# $$

# %% [markdown]
# And lastly for $Z$
#
# $$
# Z = c_1^{†}c_1 - c_2^{†} c_2 = \frac{γ_0 - iγ_1}{2}\frac{γ_0 + iγ_1}{2} - \frac{γ_2 - iγ_3}{2}\frac{γ_2 + iγ_3}{2}
# $$
# $$
# = \frac{1}{4} (γ_0γ_0 +iγ_0γ_1 -iγ_1γ_0 + γ_1γ_1 - γ_2γ_2 -iγ_2γ_3 + iγ_3γ_2 - γ_3γ_3)
# $$
# $$
# = \frac{i}{2} (γ_0γ_1 + γ_2γ_3)
# $$
#
# $$
# Z = iγ_0γ_1 \text{ or } Z= iγ_2γ_3
# $$

# %% [markdown]
# ## b) Majorana Exchange gates
#
# Let's take a step towards braiding and define Majorana exchange operators
#  - Find unitaries $B_{ij}$ that exchange the Majoranas $γ_i$ and $γ_j$, meaning it should act as
#  $$
#  B_{ij} γ_i B_{ij}^{†} = γ_j
#  $$
#   $$
#  B_{ij} γ_j B_{ij}^{†} = -γ_i
#  $$
#  and trivially on other operators. Express the gates in terms of $γ_i$ and  $γ_j$ as well as in the basis $\ket{+ -}$, $\ket{-+}$
#
#  - Check the $B_{ij}^{2}$ of these operators, how are they related to the Pauli operators?
#  - Express the Hadamard gate in terms of exchange gates
#  - Bonus: Do the same relations hold in the even parity sector?

# %% [markdown]
# ### Find unitaries
#
# If $\displaystyle  B_{ij} = \sqrt{\frac{i}{2}} (1-γ_iγ_j)$, then $\displaystyle  B_{ij}^{†} = \frac{1-i}{2} (1+γ_iγ_j)$ from $(AB)^{†} = B^{†}A^{†}$
#
# In order to express the gates in terms of the basis $\ket{+ - } $, $\ket{-+}$, I will project the matrix $B_{ij}$ into the $2× 2$ odd subspace.
# In the full $4× 4$ Hilbert space, $\ket{+-} = [0,1,0,0]^T$ and $\ket{+-} = [0,0,1,0]^T$.
#
# $$
# B_{ij}^{(2\times 2)} =
# \begin{pmatrix}
#   \bra{+ - } B_{ij} \ket{+-} & \bra{+ - } B_{ij} \ket{-+}\\
#   \bra{- + } B_{ij} \ket{+-} & \bra{- + } B_{ij} \ket{-+}
# \end{pmatrix}
# $$
# By doing this, we obtain a few different braiding matrices. Comparing them to the pauli matrices we see that
# $$
# \begin{aligned}
# B²_{12} &= X\\
# B²_{03} &= -X\\
# B²_{02} &= -Y\\
# B²_{13} &= -Y\\
# B²_{01} &= Z\\
# B²_{23} &= -Z
# \end{aligned}
# $$

# %% [markdown]
# ### Imports and configs

# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import njit

np.set_printoptions(precision=3, suppress=True)

plt.rcParams.update({
    'font.size': 12,
    "figure.figsize":(8,6),
    "axes.grid": True,
    "grid.color": "#cccccc",
    "grid.linestyle": "--",
    "axes.prop_cycle": plt.cycler(color=['#0f7e92', '#b90636', '#11793e', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])
})

# %% [markdown]
# ### Braiding operator in terms of Majoranas

# %%
"""Check properties of the Braiding operators"""
def pauli_matrices():
    X = np.array([[0, 1], [1, 0]])
    Y = np.array([[0, -1j], [1j, 0]])
    Z = np.array([[1, 0], [0, -1]])
    I = np.eye(2)
    return X, Y, Z, I

X, Y, Z, I = pauli_matrices()

Hadamard = np.array([[1, 1], [1, -1]]) / np.sqrt(2)

def majorana_operators():
    """
    Using the standard Majorana representation from JW transformation for simplicity
    """
    gamma0 = np.kron(X,I)
    gamma1 = np.kron(Y,I)
    gamma2 = np.kron(Z,X)
    gamma3 = np.kron(Z,Y)
    return gamma0, gamma1, gamma2, gamma3

def braiding_operators(i,j):
    """
    Returns braiding operators for adjacent Majorana operators
    """
    return np.sqrt(1j/2) * (np.kron(I,I) - i@j)


def test_braiding_ops():
    """
    Test the braiding operators
    """
    gamma0, gamma1, gamma2, gamma3 = majorana_operators()
    b01 = braiding_operators(gamma0, gamma1)
    b12 = braiding_operators(gamma1, gamma2)
    b23 = braiding_operators(gamma2, gamma3)
        
    # Check if they are unitary
    assert np.allclose(np.eye(4), b01 @ b01.conj().T), "b01 is not unitary"
    assert np.allclose(np.eye(4), b12 @ b12.conj().T), "b12 is not unitary"
    assert np.allclose(np.eye(4), b23 @ b23.conj().T), "b23 is not unitary"

    assert np.allclose(b01 @ gamma0 @ b01.conj().T, gamma1), "b01 does not braid gamma0 to gamma1"
    assert np.allclose(b01 @ gamma1 @ b01.conj().T, -gamma0), "b01 does not braid gamma1 to gamma0"
    assert np.allclose(b12 @ gamma1 @ b12.conj().T, gamma2), "b12 does not braid gamma1 to gamma2"
    assert np.allclose(b12 @ gamma2 @ b12.conj().T, -gamma1), "b12 does not braid gamma2 to gamma1"
    assert np.allclose(b23 @ gamma2 @ b23.conj().T, gamma3), "b23 does not braid gamma2 to gamma3"
    assert np.allclose(b23 @ gamma3 @ b23.conj().T, -gamma2), "b23 does not braid gamma3 to gamma2"

    print("All tests passed!")

test_braiding_ops()
# Out:
# All tests passed!

# %% [markdown]
# ### Braiding operators in $\ket{+-}$, $\ket{-+}$ basis

# %%
# """ Express B in the \ket{+-}, \ket{+-} basis"""
ket_pm = np.array([0, 1, 0, 0])
ket_mp = np.array([0, 0, 1, 0])

def project_to_odd_subspace(B):
    # Basis vectors for |+-⟩ and |-+⟩    
    return np.array([
        [ket_pm.conj() @ B @ ket_pm, ket_pm.conj() @ B @ ket_mp],
        [ket_mp.conj() @ B @ ket_pm, ket_mp.conj() @ B @ ket_mp]
    ])


def test_projected_braiding_ops():
    #Check if  X = B²_12 = B²_03 / Y = B²_02 = B²_13 / Z = B²_01 = B²_23
    gamma0, gamma1, gamma2, gamma3 = majorana_operators()
    # X
    b12 = braiding_operators(gamma1, gamma2)
    b03 = braiding_operators(gamma0, gamma3)
    # Y
    b02 = braiding_operators(gamma0, gamma2)
    b13 = braiding_operators(gamma1, gamma3)
    # Z
    b01 = braiding_operators(gamma0, gamma1)
    b23 = braiding_operators(gamma2, gamma3)

    b12_odd = project_to_odd_subspace(b12)
    b03_odd = project_to_odd_subspace(b03)

    b02_odd = project_to_odd_subspace(b02)
    b13_odd = project_to_odd_subspace(b13)

    b01_odd = project_to_odd_subspace(b01)
    b23_odd = project_to_odd_subspace(b23)

    #square
    b12_odd_sq = b12_odd @ b12_odd
    b03_odd_sq = b03_odd @ b03_odd
    b02_odd_sq = b02_odd @ b02_odd
    b13_odd_sq = b13_odd @ b13_odd
    b01_odd_sq = b01_odd @ b01_odd
    b23_odd_sq = b23_odd @ b23_odd

    assert np.allclose(b12_odd_sq, X), "B²_12 is not X"
    assert np.allclose(b03_odd_sq, -X), "B²_03 is not -X"
    assert np.allclose(b02_odd_sq, -Y), "B²_02 is not -Y"
    assert np.allclose(b13_odd_sq, -Y), "B²_13 is not -Y"
    assert np.allclose(b01_odd_sq, Z), "B²_01 is not Z"
    assert np.allclose(b23_odd_sq, -Z), "B²_23 is not -Z"
    assert np.allclose(b01_odd@b12_odd@b01_odd,np.exp(1j*np.pi/4)*Hadamard), "B_01 B_12 B_01 is not exp(iπ/4) Hadamard"

    print("All tests passed!")
    print("Projected braiding operators:")
    print("B²_12 ∼ X")
    print("B²_03 ∼ -X")
    print("B²_02 ∼ -Y")
    print("B²_13 ∼ -Y")
    print("B²_01 ∼ Z")
    print("B²_23 ∼ -Z")
    print("B_01 B_12 B_01 ∼ Hadamard")
test_projected_braiding_ops()
# Out:
# All tests passed!
# Projected braiding operators:
# B²_12 ∼ X
# B²_03 ∼ -X
# B²_02 ∼ -Y
# B²_13 ∼ -Y
# B²_01 ∼ Z
# B²_23 ∼ -Z
# B_01 B_12 B_01 ∼ Hadamard

# %% [markdown]
# ## c) Jordan-Wigner transform
#
# While we have a map between Majorana operators and Pauli operators acting on a subspace of a specific parity, we need to create yet another map in order to look at the braiding protocol. We saw how four Majoranas can make a qubit. In the braiding protocol, an additional pair of Majoranas will be used to make an exchange. In the braiding protocol, an additional pair of Majoranas will be used to make an exchange. The braiding protocol therefore needs six Majoranas to work. Four to make a qubit, and two extra auxiliary Majoranas to make the braid.
#
# The braiding protocol in [C. W. J. Beenakker] is expressed in terms of four Majoranas. One pair is "half" the qubit and one qubit is the auxiliary ones. To interret the result in terms of a qubit, an additional pair must be added. See [A. Tsintzis, R. S. Souto, K. Flensberg, J. Danon, and M. Leijnse] to see the protocol with all six Majoranas.
#
# To implement the Hamiltonian numerically, we should map the fermions to Pauli operators and tensor products of those. We already did so, but that was only mapping the operators in a specific parity sector. Now we want to be more general and express it in the full Hilbert space, in a version which is simple to implement numerically.
#
# The general form that the Hamiltonian takes during the braiding protocol is
# $$
# H(t) = ∑_{j=1}^{3} Δ_j i(t) γ_0γ_j
# $$
# Write down the representation of the Majorana operators in terms of tensor products of local Pauli
# or spin operators.

# %%
def tensor_product(arrays):
    """
    Computes the tensor product of a list of arrays
    """
    result = arrays[0]
    for array in arrays[1:]:
        result = np.kron(result, array)
    return result


def creation_operator(j:int, N:int) -> np.ndarray:
    """
    Returns the creation operator for a particle at site j for a N-site system
    """
    operators = [I] * N

    z_op = operators.copy()
    for i in range(j):
        z_op[i] = Z
    
    z_op = tensor_product(z_op)
    x_op = operators.copy()
    x_op[j] = X
    x_op = tensor_product(x_op)
    y_op = operators.copy()
    y_op[j] = Y
    y_op = tensor_product(y_op)
    return 0.5 * z_op @ (x_op + 1j*y_op)


def annihilation_operator(j:int, N:int) -> np.ndarray:
    """
    Returns the annihilation operator for a particle at site j for a N-site system
    """
    operators = [I] * N
    z_op = operators.copy()
    for i in range(j):
        z_op[i] = Z
    
    z_op = tensor_product(z_op)
    x_op = operators.copy()
    x_op[j] = X
    x_op = tensor_product(x_op)
    y_op = operators.copy()
    y_op[j] = Y
    y_op = tensor_product(y_op)
    return 0.5 * z_op @ (x_op - 1j*y_op)


def majorana_ops(j:int, N:int) -> np.ndarray:
    """
    Returns the Majorana operators for a particle at site j for a N-site system
    Order (gamma_{2j-1}, gamma_{2j})
    """
    cj = annihilation_operator(j, N)
    cj_dagger = creation_operator(j, N)
    gamma1 = cj_dagger + cj
    gamma2 = 1j * (cj - cj_dagger)
    return gamma1, gamma2


def test_expected_majorana_ops():
    """
    Test the expected Majorana operators
    """
    g0,g1 = majorana_ops(0,3) ## 0 refers to c_1
    g2,g3 = majorana_ops(1,3) ## 1 refers to c_2
    g4,g5 = majorana_ops(2,3) ## 2 refers to c_3

    #Check anticommutation relations
    gammas = [g0,g1,g2,g3,g4,g5]
    for i in range(len(gammas)):
        for j in range(i+1, len(gammas)):
            assert np.allclose(gammas[i] @ gammas[j] + gammas[j] @ gammas[i], 0), f"gamma{i} and gamma{j} do not anticommute"

    assert np.allclose(tensor_product([X,I,I]), g0), "gamma0 does not match"
    assert np.allclose(tensor_product([Y,I,I]), g1), "gamma1 does not match"
    assert np.allclose(tensor_product([Z,X,I]), g2), "gamma2 does not match"
    assert np.allclose(tensor_product([Z,Y,I]), g3), "gamma3 does not match"
    assert np.allclose(tensor_product([Z,Z,X]), g4), "gamma4 does not match"
    assert np.allclose(tensor_product([Z,Z,Y]), g5), "gamma5 does not match"

    print("All tests passed!")

test_expected_majorana_ops()
# Out:
# All tests passed!

# %% [markdown]
# ## d) Implement the Hamiltonian numerically
# With the operators expressed as Pauli operators, they can be implemented numerically by a tensor product.
#
# We also need to express the parameters $Δ_j(t)$ as a function of time. One suggestion is to parameterize it using the following parameters.
#  - $Δ_{\max}$ is a large value that the coupling takes on in those steps of the protocol where it is turned on.
#  - $Δ_{\min}$ is the value it takes when it switches off (in an ideal experiment this is zero)
#  - $s$ some parameter that determines how fast one changes from $Δ_{\min}$ to $Δ_{\max}$. The particular shape of the step is not that important, but the steepness should be tunable.
#  - $T$ is the total time of the protocol
#
# With $H(t)$ implemented, study how the energy spectrum evolves during the protocol. Does it match expectations?

# %%
@njit
def delta_pulse(t, T_peak, width, s, Delta_max, Delta_min):
    """
    Improved smooth delta pulse with controllable width and steepness
    """
    # Calculate rise and fall times
    T_start = T_peak - width/2
    T_end = T_peak + width/2
    
    # Smooth step functions
    rise = 1/(1 + np.exp(-s*(t - T_start)))
    fall = 1/(1 + np.exp(s*(t - T_end)))
    
    return Delta_min + (Delta_max - Delta_min) * rise * fall

@njit
def build_hamiltonian(t, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3):
    """
    Constructs the time-dependent Hamiltonian H(t) = Σ Δ_j(t) iγ₀γ_j
    """
    
    # Time-dependent couplings
    Δ1 = delta_pulse(t, 0, width, s, Delta_max, Delta_min) + delta_pulse(t, T_total, width, s, Delta_max, Delta_min)
    Δ2 = delta_pulse(t, T_total/3, width, s, Delta_max, Delta_min)
    Δ3 = delta_pulse(t, 2*T_total/3, width, s, Delta_max, Delta_min)
    # Δ1 += delta_pulse(t, T_total, width, s, Delta_max, Delta_min)


    # Construct Hamiltonian terms
    H = (Δ1 * 1j * g0 @ g1 + 
         Δ2 * 1j * g0 @ g2 + 
         Δ3 * 1j * g0 @ g3)
    
    return H, (Δ1, Δ2, Δ3)

def analyze_spectrum(T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3, n_points=1000):
    times = np.linspace(0, T_total, n_points)
    energies = np.zeros((n_points, 4))  # Store all 4 eigenvalues
    couplings = np.zeros((n_points, 3))  # Store Δ1, Δ2, Δ3
    
    for i, t in enumerate(times):
        H, couplings[i] = build_hamiltonian(t, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3)
        
        e_vals = np.linalg.eigvalsh(H)
        energies[i] = e_vals
        # couplings[i] = np.array([Δ1, Δ2, Δ3])
    
    return times, energies, couplings

def plot_results(times, energies, couplings):
    plt.figure(figsize=(12, 8))
    
    # Plot energy spectrum
    plt.subplot(2, 1, 1)
    for i in range(4):
        plt.plot(times, energies[:, i], label=f'E{i}')
    plt.ylabel('Energy')
    plt.title('Energy Spectrum Evolution')
    plt.legend()
    
    # Plot couplings
    plt.subplot(2, 1, 2)
    labels = ['Δ₁(t)', 'Δ₂(t)', 'Δ₃(t)']
    for i in range(3):
        plt.plot(times, couplings[:, i], label=labels[i])
    plt.xlabel('Time')
    plt.ylabel('Coupling Strength')
    plt.title('Time-Dependent Couplings')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Get Majorana operators
g0, g1 = majorana_ops(0, 2)  # γ₀, γ₁
g2, g3 = majorana_ops(1, 2)  # γ₂, γ₃

T_total = 20.0
Delta_max = 10.0
Delta_min = 0.01
s = 10.0
width = T_total/3
# Parameters
params = {
    'T_total': T_total,
    'Delta_max': Delta_max,
    'Delta_min': Delta_min,
    's': s,
    'width': width,
    'g0': g0,
    'g1': g1,
    'g2': g2,
    'g3': g3,
    'n_points': 1000
}

# Run analysis
times, energies, couplings = analyze_spectrum(**params)

# Visualize
plot_results(times, energies, couplings)

# %% [markdown]
# ## e) Implement braiding protocol
# Now we are readu to solve the Schrodinger equation
# $$
# \frac{∂}{∂t} \ket{ ψ_t} = -i H_t \ket{ψ_t}
# $$
# The simplest way to do so is to approximate
# $$
# dt \frac{∂ }{∂t} \ket{ψ_t} ≈ \ket{ψ_{t+dt}} - \ket{ψ_t}
# $$
# and express the state at $t+dt$ in terms of the state at $t$. Then given an inital state, take short steps until reaching the final time $T$. The numerical error can be monitored by looking at the norm of the state, i.e. $\bra{ψ_t} \ket{ψ_t}$. How much this deviates from 1 gives a measure of how accurate the solution is.
#  - Find parameters so that the protocol succeeds and implements the desired exchange gate
#  - Calculate the Berry phase with the berry connection $A = i \bra{ dψ} \ket{ψ}$
#  - Measure parities during the protocol. Do they behave as expected?

# %%
from scipy.linalg import expm
@njit
def fidelity(psi, phi):
    """
    Calculate the fidelity between two wavefunctions
    """
    return np.abs(np.vdot(psi, phi))**2

@njit(debug=True)
def compute_gradient(psi, dt):
    # n_times = psi.shape[0]
    grad = np.zeros_like(psi, dtype=np.complex128)
    # Central difference for interior points
    grad[1:-1] = (psi[2:] - psi[:-2]) / (2 * dt)
    # Forward difference for the first point
    grad[0] = (psi[1] - psi[0]) / dt
    # Backward difference for the last point
    grad[-1] = (psi[-1] - psi[-2]) / dt
    return grad

@njit
def berry_connection(psi,dt):
    """
    Compute Berry connection A(t) = i <psi(t) | d/dt psi(t)>
    psi: shape (timesteps, dim)
    """
    dpsi_dt = compute_gradient(psi, dt)
    A_t = np.zeros(psi.shape[0], dtype=np.complex128)
    for i in range(psi.shape[0]):
        A_t[i] = 1j * np.vdot(psi[i], dpsi_dt[i])
    return A_t   

@njit
def berry_phase(psi,dt):
    """
    Compute Berry phase γ = ∫ A(t) dt
    """
    return np.trapz(berry_connection(psi,dt), dx=dt)


@njit
def evolve_wavefunction(psi0, target ,T_total, Delta_max, Delta_min, s, width,g0,g1,g2,g3, n_steps=1000):
    dt = T_total / n_steps
    times = np.linspace(0, T_total, n_steps)
    psi = np.zeros((n_steps, 4), dtype=np.complex128)
    psi[0] = psi0

    couplings = np.zeros((n_steps, 3))  # Store Δ1, Δ2, Δ3

    norms = np.zeros(n_steps)
    norms[0] = np.linalg.norm(psi[0])

    fidel = np.zeros(n_steps)
    fidel[0] = np.abs(np.vdot(psi[0], target))**2

    berryphase = np.zeros(n_steps, dtype=np.complex128)

    evals = np.zeros((n_steps, 4))  # Store all 4 eigenvalues
    
    for i in range(1, n_steps):
        H, (Δ1, Δ2, Δ3) = build_hamiltonian(times[i], T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3)
        e_vals = np.linalg.eigvalsh(H)
        evals[i] = e_vals
        psi[i] =psi[i-1] - 1j * H @ psi[i-1] * dt  #expm(-1j * H * dt)  @ psi[i-1] #
        norm = np.linalg.norm(psi[i]) 
        psi[i] /= norm  # Normalize the wavefunction
        norms[i] = norm
        couplings[i] = np.array([Δ1, Δ2, Δ3])
        fidel[i] = fidelity(psi[i], target)
        berryphase[i] = berry_phase(psi[:i+1],dt)

    return times, psi, norms, couplings, fidel, berryphase

def plot_evolution(times, psi, norms, couplings, fidelity, berry_phase):
    plt.figure(figsize=(12, 12))
    
    # Plot wavefunction probabilities
    plt.subplot(3, 1, 1)
    plt.plot(times, np.abs(psi[:, 0])**2, label='|00⟩')
    plt.plot(times, np.abs(psi[:, 1])**2, label='|01⟩')
    plt.plot(times, np.abs(psi[:, 2])**2, label='|10⟩')
    plt.plot(times, np.abs(psi[:, 3])**2, label='|11⟩')
    # plt.xlabel('Time')
    plt.ylabel('Probability')
    plt.title('Wavefunction Probabilities')
    plt.legend()
    
    # Plot norm
    plt.subplot(3, 1, 2)
    plt.plot(times, norms)
    plt.axhline(1, color='r', linestyle='--', label='Norm = 1')
    # plt.xlabel('Time')
    plt.ylabel('Norm')
    plt.ylim(-0.1, 1.2)
    plt.title('Norm of the Wavefunction')
    plt.legend()
    
    # Plot couplings
    plt.subplot(3, 1, 3)
    labels = ['Δ₁(t)', 'Δ₂(t)', 'Δ₃(t)']
    for i in range(3):
        plt.plot(times, couplings[:, i], label=labels[i])
    plt.xlabel('Time')
    plt.ylabel('Coupling Strength')
    plt.title('Time-Dependent Couplings')
    plt.legend()
    
    # Plot fidelityity
    fig, ax = plt.subplots(figsize=(12, 4))
    ax.plot(times, fidelity)
    ax.set_xlabel('Time', fontsize=12)
    ax.set_ylabel('Fidelity', fontsize=12)
    ax.set_title('Fidelity of the Wavefunction', fontsize=12)
    ax.axhline(1, color='r', linestyle='--', label='Fidelity = 1')
    ax.legend()
    plt.show()
    # Plot Berry phase
    plt.figure(figsize=(12, 6))
    plt.plot(times, berry_phase, label='Berry Phase') 
    plt.xlabel('Time', fontsize=12)    
    # plt.axhline(berry_phase[-1], color='r', linestyle='--', label=f'Berry Phase = {berry_phase_pi.real:.2f}π')
    plt.ylabel('Berry Phase', fontsize=12)
    plt.title('Berry Phase of the Wavefunction', fontsize=12)
    plt.legend()
    plt.show()


g0, g1 = majorana_ops(0, 2)  # γ₀, γ₁
g2, g3 = majorana_ops(1, 2)  # γ₂, γ₃
b01 = braiding_operators(g0, g1)
b02 = braiding_operators(g0, g2)
b03 = braiding_operators(g0, g3)
b12 = braiding_operators(g1, g2)


T_total = 20.0
Delta_max = 10.0
Delta_min = 0.01
s = 5.0
width = T_total/3

psi0 = Delta_max * np.array([1j*(np.sqrt(3) + 1), 0, 0, 1j+1], dtype=np.complex128)  # Initial state |01⟩

psi0 /= np.linalg.norm(psi0)  # Normalize the initial state

controll_braid = b12 # = i(g0g1 + g0g2 + g0g3)
target = controll_braid @ psi0
target /= np.linalg.norm(target)


# Parameters
params = {
    'T_total': T_total,
    'Delta_max': Delta_max,
    'Delta_min': Delta_min,
    's': s,
    'width': width,
    'g0': g0,
    'g1': g1,
    'g2': g2,
    'g3': g3,
    'n_points': 1000
}

times, psi, norms, couplings, fidelity, berry_phase = evolve_wavefunction(psi0, target, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3, n_steps=1000)
plot_evolution(times, psi, norms, couplings, fidelity, berry_phase)
# Out:
# /tmp/ipykernel_4145/2159464537.py:70: NumbaDebugInfoWarning: Could not find source for function: <function __numba_array_expr_0x7e41f0ba4410 at 0x7e41e24f91c0>. Debug line information may be inaccurate.
#   berryphase[i] = berry_phase(psi[:i+1],dt)
# /tmp/ipykernel_4145/2159464537.py:70: NumbaDebugInfoWarning: Could not find source for function: <function __numba_array_expr_0x7e41f0ba5a00 at 0x7e41e23b2980>. Debug line information may be inaccurate.
#   berryphase[i] = berry_phase(psi[:i+1],dt)
# /tmp/ipykernel_4145/2159464537.py:70: NumbaDebugInfoWarning: Could not find source for function: <function __numba_array_expr_0x7e41f0ba5eb0 at 0x7e41e24f82c0>. Debug line information may be inaccurate.
#   berryphase[i] = berry_phase(psi[:i+1],dt)
# /tmp/ipykernel_4145/2159464537.py:70: NumbaDebugInfoWarning: Could not find source for function: <function compute_gradient at 0x7e41f0998f40>. Debug line information may be inaccurate.
#   berryphase[i] = berry_phase(psi[:i+1],dt)
# /home/hishem/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/hishem/miniconda3/envs/myenv/lib/python3.12/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# ## d) Implement the Hamiltonian numerically -Restart

# %%
import numpy as np
from numba import njit
import matplotlib.pyplot as plt

@njit
def delta_pulse(t, T_peak, width, s, Delta_max, Delta_min):
    """
    Improved smooth delta pulse with controllable width and steepness
    """
    # Calculate rise and fall times
    T_start = T_peak - width/2
    T_end = T_peak + width/2
    
    # Smooth step functions
    rise = 1/(1 + np.exp(-s*(t - T_start)))
    fall = 1/(1 + np.exp(s*(t - T_end)))
    
    return Delta_min + (Delta_max - Delta_min) * rise * fall

@njit
def build_hamiltonian(t, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3):
    """
    Constructs the time-dependent Hamiltonian H(t) = Σ Δ_j(t) iγ₀γ_j
    """
    
    # Time-dependent couplings
    Δ1 = delta_pulse(t, T_total/4, width, s, Delta_max, Delta_min)
    Δ2 = delta_pulse(t, T_total/2, width, s, Delta_max, Delta_min)
    Δ3 = delta_pulse(t, 3*T_total/4, width, s, Delta_max, Delta_min)


    # Construct Hamiltonian terms
    H = (Δ1 * 1j * g0 @ g1 + 
         Δ2 * 1j * g0 @ g2 + 
         Δ3 * 1j * g0 @ g3)
    
    return H, (Δ1, Δ2, Δ3)

def analyze_spectrum(T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3, n_points=1000):
    times = np.linspace(0, T_total, n_points)
    energies = np.zeros((n_points, 4))  # Store all 4 eigenvalues
    couplings = np.zeros((n_points, 3))  # Store Δ1, Δ2, Δ3
    
    for i, t in enumerate(times):
        H, couplings[i] = build_hamiltonian(t, T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3)
        
        e_vals = np.linalg.eigvalsh(H)
        energies[i] = e_vals
        # couplings[i] = np.array([Δ1, Δ2, Δ3])
    
    return times, energies, couplings

def plot_results(times, energies, couplings):
    plt.figure(figsize=(12, 8))
    
    # Plot energy spectrum
    plt.subplot(2, 1, 1)
    for i in range(4):
        plt.plot(times, energies[:, i], label=f'E{i}')
    plt.ylabel('Energy')
    plt.title('Energy Spectrum Evolution')
    plt.legend()
    
    # Plot couplings
    plt.subplot(2, 1, 2)
    labels = ['Δ₁(t)', 'Δ₂(t)', 'Δ₃(t)']
    for i in range(3):
        plt.plot(times, couplings[:, i], label=labels[i])
    plt.xlabel('Time')
    plt.ylabel('Coupling Strength')
    plt.title('Time-Dependent Couplings')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# Get Majorana operators
g0, g1 = majorana_ops(0, 2)  # γ₀, γ₁
g2, g3 = majorana_ops(1, 2)  # γ₂, γ₃

# Parameters
params = {
    'T_total': 20.0,
    'Delta_max': 10.0,
    'Delta_min': 0.1,
    's': 5.0,
    'width': 4.0,
    'g0': g0,
    'g1': g1,
    'g2': g2,
    'g3': g3,
    'n_points': 1000
}

# Run analysis
times, energies, couplings = analyze_spectrum(**params)

# Visualize
plot_results(times, energies, couplings)

# %% [markdown]
# ## e) Implement braiding protocol -Restart

# %%
from scipy.linalg import expm
@njit
def fidelity(psi, phi):
    """
    Calculate the fidelity between two wavefunctions
    """
    return np.abs(np.vdot(psi, phi))**2

@njit(debug=True)
def compute_gradient(psi, dt):
    n = psi.shape[0]
    grad = np.zeros_like(psi, dtype=np.complex128)
    for i in range(0, n - 1):
        grad[i] = (psi[i + 1] - psi[i]) / dt
    grad[-1] = grad[-2]  
    return grad

@njit(debug=True)
def berry_connection(psi, dt):
    dpsi_dt = compute_gradient(psi, dt)
    A_t = np.zeros(psi.shape[0], dtype=np.complex128)
    for i in range(psi.shape[0]):
        A_t[i] = -1j * np.dot(np.conj(psi[i]), dpsi_dt[i])
    return A_t

@njit(debug=True)
def berry_phase(psi, dt):
    A_t = berry_connection(psi, dt)
    return np.cumsum(A_t) * dt


    # phase = np.zeros(psi.shape[0], dtype=np.complex128)
    # for i in range(len(A_t)):
    #     phase[i] = 




# @njit(debug=True)   
# def berry_phase(psi,dt):

#     n = psi.shape[0]
#     phase = np.zeros(n, dtype=np.complex128)
#     phase[0] = berry_connection(psi[0], dt)
#     for i in range(1, n):
#         phase[i] = phase[i-1] + berry_connection(psi[i], dt)
#     return phase
# @njit 
# def berry_phase(psi, dt):

#     n_steps = psi.shape[0]
#     phase = 0.0
#     for i in range(1, n_steps):
#         overlap = np.vdot(psi[i], psi[i-1])
#         phase += np.arctan2(overlap.imag, overlap.real)
#     return phase * dt


# @njit
# def calculate_parity(psi):
#     """
#     Calculate the parity of the wavefunction
#     """


# @njit
def evolve_wavefunction(psi0, target ,T_total, Delta_max, Delta_min, s, width,g0,g1,g2,g3, n_steps=1000):
    dt = T_total / n_steps
    times = np.linspace(0, T_total, n_steps)
    psi = np.zeros((n_steps, 4), dtype=np.complex128)
    psi[0] = psi0

    couplings = np.zeros((n_steps, 3))  # Store Δ1, Δ2, Δ3

    norms = np.zeros(n_steps)
    norms[0] = np.linalg.norm(psi[0])

    fidel = np.zeros(n_steps)
    fidel[0] = np.abs(np.vdot(psi[0], target))**2

    berryphase = np.zeros(n_steps, dtype=np.complex128)

    evals = np.zeros((n_steps, 4))  # Store all 4 eigenvalues

    for i in range(1, n_steps):
        H, (Δ1, Δ2, Δ3) = build_hamiltonian(times[i], T_total, Delta_max, Delta_min, s, width, g0, g1, g2, g3)
        e_vals = np.linalg.eigvalsh(H)
        evals[i] = e_vals
        psi[i] = expm(-1j * H * dt)  @ psi[i-1] #psi[i-1] - 1j * H @ psi[i-1] * dt  #
        norm = np.linalg.norm(psi[i]) 
        # psi[i] /= norm  # Normalize the wavefunction
        norms[i] = norm
        couplings[i] = np.array([Δ1, Δ2, Δ3])
        fidel[i] = fidelity(psi[i], target)
    berryphase = berry_phase(psi[:i+1],dt)

    # berryphase = n_berry_phase(psi,dt)
    # b_phase = berry_phase(psi,dt)


    return times, psi, norms, couplings, fidel, berryphase

def plot_evolution(times, psi, norms, couplings, fidelity, berry_phase):
    plt.figure(figsize=(12, 12))
    
    # Plot wavefunction probabilities
    plt.subplot(3, 1, 1)
    plt.plot(times, np.abs(psi[:, 0])**2, label='|00⟩')
    plt.plot(times, np.abs(psi[:, 1])**2, label='|01⟩')
    plt.plot(times, np.abs(psi[:, 2])**2, label='|10⟩')
    plt.plot(times, np.abs(psi[:, 3])**2, label='|11⟩')
    # plt.xlabel('Time')
    plt.ylabel('Probability')
    plt.title('Wavefunction Probabilities')
    plt.legend()
    
    # Plot norm
    plt.subplot(3, 1, 2)
    plt.plot(times, norms)
    plt.axhline(1, color='r', linestyle='--', label='Norm = 1')
    # plt.xlabel('Time')
    plt.ylabel('Norm')
    plt.ylim(-0.1, 1.2)
    plt.title('Norm of the Wavefunction')
    plt.legend()
    
    # Plot couplings
    plt.subplot(3, 1, 3)
    labels = ['Δ₁(t)', 'Δ₂(t)', 'Δ₃(t)']
    for i in range(3):
        plt.plot(times, couplings[:, i], label=labels[i])
    plt.xlabel('Time')
    plt.ylabel('Coupling Strength')
    plt.title('Time-Dependent Couplings')
    plt.legend()
    
    # Plot fidelityity
    fig, ax = plt.subplots(figsize=(12, 4))
    ax.plot(times, fidelity,label=f"Fidelity numeric: {fidelity[-1]:.2f}")
    ax.set_xlabel('Time', fontsize=12)
    ax.set_ylabel('Fidelity', fontsize=12)
    ax.set_title('Fidelity of the Wavefunction', fontsize=12)
    ax.axhline(1, color='r', linestyle='--', label='Fidelity = 1')
    ax.legend()
    plt.show()
    # Plot Berry phase

    plt.figure(figsize=(12, 6))
    plt.plot(times, berry_phase.real, label='Total Berry Phase') 
    plt.xlabel('Time', fontsize=12)    
    plt.axhline(berry_phase[-1].real, color='r', linestyle='--', label=f'Berry Phase = {berry_phase[-1].real:.2f}π')
    plt.ylabel('Berry Phase', fontsize=12)
    plt.title('Berry Phase of the Wavefunction', fontsize=12)
    plt.legend()
    plt.show()




g0, g1 = majorana_ops(0, 2)  # γ₀, γ₁
g2, g3 = majorana_ops(1, 2)  # γ₂, γ₃
b01 = braiding_operators(g0, g1)
b02 = braiding_operators(g0, g2)
b03 = braiding_operators(g0, g3)

psi0 = np.array([0, 1, 0, 0], dtype=np.complex128)  # Initial state |01⟩

controll_braid = b01@b02@b03 # = i(g0g1 + g0g2 + g0g3)
target = controll_braid @ psi0
target /= np.linalg.norm(target)

params = {
    'T_total': 20.0,
    'Delta_max': 10.0,
    'Delta_min': 0.001,
    's': 5.0,
    'width': 5.0,
    'g0': g0,
    'g1': g1,
    'g2': g2,
    'g3': g3,
    'n_steps': 5000
}

times, psi, norms, couplings, fidel, berry_phase  = evolve_wavefunction(psi0, target, **params)

plot_evolution(times, psi, norms, couplings, fidel, berry_phase)

for b in berry_phase:
    print(b)
# Out:
# /tmp/ipykernel_4145/3277059501.py:28: NumbaDebugInfoWarning: Could not find source for function: <function __numba_array_expr_0x7e41e17d7bc0 at 0x7e41f3c32700>. Debug line information may be inaccurate.
#   A_t = berry_connection(psi, dt)
# /tmp/ipykernel_4145/3277059501.py:28: NumbaDebugInfoWarning: Could not find source for function: <function __numba_array_expr_0x7e41f0e18ef0 at 0x7e41f1c34400>. Debug line information may be inaccurate.
#   A_t = berry_connection(psi, dt)
# /tmp/ipykernel_4145/3277059501.py:28: NumbaDebugInfoWarning: Could not find source for function: <function berry_connection at 0x7e41f1aab740>. Debug line information may be inaccurate.
#   A_t = berry_connection(psi, dt)
# /tmp/ipykernel_4145/3277059501.py:28: NumbaDebugInfoWarning: Could not find source for function: <function compute_gradient at 0x7e41f1aa9f80>. Debug line information may be inaccurate.
#   A_t = berry_connection(psi, dt)
# /home/hishem/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/lowering.py:116: NumbaDebugInfoWarning: Could not find source for function: <function berry_phase at 0x7e41f19af380>. Debug line information may be inaccurate.
#   warnings.warn(NumbaDebugInfoWarning(msg))
# /home/hishem/miniconda3/envs/myenv/lib/python3.12/site-packages/numba/core/lowering.py:116: NumbaDebugInfoWarning: Could not find source for function: <function __numba_array_expr_0x7e41e1b67e60 at 0x7e41e1c88220>. Debug line information may be inaccurate.
#   warnings.warn(NumbaDebugInfoWarning(msg))
# (4.152062284856907e-06+2.461986170487762e-11j)
# (8.30719704038045e-06+4.9252381598678446e-11j)
# (1.2465466346648921e-05+7.389805571978472e-11j)
# (1.6626933538074483e-05+9.855696951710782e-11j)
# (2.079166322874671e-05+1.2322954652774597e-10j)
# (2.4959721338288125e-05+1.4791596404269954e-10j)
# (2.9131175118232154e-05+1.7261634516458963e-10j)
# (3.3306093178934027e-05+1.9733139417012008e-10j)
# (3.7484545517025374e-05+2.2206114368801244e-10j)
# (4.166660354342348e-05+2.468058104737939e-10j)
# (4.585234011190655e-05+2.715659842017733e-10j)
# (5.0041829548266116e-05+2.963419272068731e-10j)
# (5.423514768004866e-05+3.211338725320855e-10j)
# (5.843237186689796e-05+3.459422100345136e-10j)
# (6.263358103151052e-05+3.707672274583753e-10j)
# (6.683885569121653e-05+3.9560940565029887e-10j)
# (7.104827799019861e-05+4.2046904664545986e-10j)
# (7.52619317323618e-05+4.453464558430125e-10j)
# (7.947990241486746e-05+4.702421231316842e-10j)
# (8.370227726234468e-05+4.951562368032988e-10j)
# (8.792914526179305e-05+5.200894176041328e-10j)
# (9.216059719819037e-05+5.450420083587968e-10j)
# (9.639672569081982e-05+5.700143616263344e-10j)
# (0.00010063762523033129+5.950070151337316e-10j)
# (0.00010488339221655109+6.200201998425493e-10j)
# (0.00010913412499705593+6.4505456799417e-10j)
# (0.00011338992390652597+6.701105875860118e-10j)
# (0.00011765089130689297+6.951884906222148e-10j)
# (0.00012191713162829971+7.202887751020629e-10j)
# (0.0001261887514108868+7.454121504853822e-10j)
# (0.00013046585934742375+7.705589265960073e-10j)
# (0.0001347485663268012+7.957297333024554e-10j)
# (0.00013903698547840216+8.209250174216599e-10j)
# (0.00014333123221736926+8.461452041825097e-10j)
# (0.00014763142429078706+8.713910791162731e-10j)
# (0.00015193768182479665+8.966629470391789e-10j)
# (0.00015625012737266296+9.219614546605437e-10j)
# (0.00016056888596381247+9.472873012114117e-10j)
# (0.000164894085153862+9.726410582898715e-10j)
# (0.00016922585507565807+9.980232098948147e-10j)
# (0.00017356432849134748+1.0234344125961732e-09j)
# (0.00017790964084549984+1.048875309654147e-09j)
# (0.00018226193031930328+1.0743465651660458e-09j)
# (0.00018662133788585492+1.0998487851170053e-09j)
# (0.0001909880073665688+1.1253826583427827e-09j)
# (0.0001953620854887229+1.1509489842775026e-09j)
# (0.0001997437219441689+1.1765483653794543e-09j)
# (0.00020413306944922822+1.2021814523493122e-09j)
# (0.00020853028380579788+1.2278492979855065e-09j)
# (0.00021293552396369072+1.2535523763188524e-09j)
# (0.0002173489520842355+1.279291597625132e-09j)
# (0.0002217707336051612+1.3050676555077054e-09j)
# (0.0002262010373067929+1.3308814815328962e-09j)
# (0.0002306400353795841+1.356733808939964e-09j)
# (0.00023508790349301405+1.3826255106811984e-09j)
# (0.00023954482086587645+1.4085574904648612e-09j)
# (0.00024401097033798844+1.4345307928508137e-09j)
# (0.0002484865384433478+1.460546044133642e-09j)
# (0.00025297171548476866+1.486604333347244e-09j)
# (0.00025746669561002453+1.512706868763625e-09j)
# (0.0002619716768895294+1.5388542979689778e-09j)
# (0.00026648686139558856+1.5650478008425509e-09j)
# (0.0002710124552832502+1.5912882916009686e-09j)
# (0.00027554866887279+1.6175769494505835e-09j)
# (0.0002800957167338627+1.6439147462712874e-09j)
# (0.0002846538177713528+1.6703028585999797e-09j)
# (0.0002892231953129603+1.6967425205088258e-09j)
# (0.00029380407719855494+1.7232347613493418e-09j)
# (0.00029839669587133634+1.7497809164180624e-09j)
# (0.0003030012884708349+1.7763820230389583e-09j)
# (0.0003076180969277918+1.8030394334004214e-09j)
# (0.0003122473680609556+1.8297545345889755e-09j)
# (0.0003168893536758338+1.856528574881473e-09j)
# (0.00032154431066543966+1.8833629292196192e-09j)
# (0.0003262125011130741+1.9102590265627163e-09j)
# (0.0003308941923971834+1.9372181610107727e-09j)
# (0.00033558965729833513+1.9642419636963226e-09j)
# (0.00034029917410835573+1.991331758925104e-09j)
# (0.00034502302674167156+2.0184891358663626e-09j)
# (0.00034976150484889953+2.045715737217156e-09j)
# (0.0003545149039327322+2.073013152840146e-09j)
# (0.0003592835254661638+2.1003830292114514e-09j)
# (0.00036406767701310403+2.127827061420834e-09j)
# (0.0003688676723514284+2.1553470895706545e-09j)
# (0.0003736838315985137+2.182944744257867e-09j)
# (0.00037851648133931+2.210621973195777e-09j)
# (0.0003833659547569987+2.2383806724002095e-09j)
# (0.0003882325917662897+2.266222753983176e-09j)
# (0.00039311673914941154+2.294150206230447e-09j)
# (0.0003980187506948483+2.3221650347010486e-09j)
# (0.00040293898733887785+2.350269417166518e-09j)
# (0.0004078778173099702+2.378465405998245e-09j)
# (0.00041283561627610124+2.4067553989830057e-09j)
# (0.0004178127674950426+2.4351414909116657e-09j)
# (0.00042280966196768673+2.463625926103714e-09j)
# (0.0004278266985944691+2.4922113193050592e-09j)
# (0.0004328642843349489+2.52089997852205e-09j)
# (0.00043792283437061387+2.549694327877981e-09j)
# (0.00044300277227097266+2.57859731994433e-09j)
# (0.00044810453016300183+2.6076113939205413e-09j)
# (0.00045322854890401487+2.6367391989605023e-09j)
# (0.0004583752782580233+2.665983528773703e-09j)
# (0.0004635451770756588+2.695347577351143e-09j)
# (0.0004687387134777297+2.7248339611187418e-09j)
# (0.00047395636504248413+2.7544459488110847e-09j)
# (0.0004791986189966551+2.784186679805366e-09j)
# (0.00048446597241036426+2.814059257068981e-09j)
# (0.0004897589323959613+2.8440669371224542e-09j)
# (0.0004950780163108793+2.8742131945163157e-09j)
# (0.0005004237519645867+2.9045016603486707e-09j)
# (0.000505796677829718+2.9349358233117605e-09j)
# (0.0005111973432574697+2.9655194919603766e-09j)
# (0.0005166263086973433+2.9962563523440808e-09j)
# (0.0005220841459213289+3.027150285793205e-09j)
# (0.0005275714382526142+3.0582054470959907e-09j)
# (0.0005330887807989117+3.0894259914624035e-09j)
# (0.0005386367806904986+3.1208161158039266e-09j)
# (0.0005442160573230628+3.1523803026846597e-09j)
# (0.0005498272426054525+3.1841229891383274e-09j)
# (0.0005554709812124295+3.216048880928236e-09j)
# (0.0005611479308425254+3.2481628013327287e-09j)
# (0.0005668587624811036+3.2804696288491835e-09j)
# (0.0005726041606687354+3.3129744340933497e-09j)
# (0.0005783848237749925+3.345682482057467e-09j)
# (0.0005842014642777697+3.3785992099491006e-09j)
# (0.0005900548090482456+3.4117300687607493e-09j)
# (0.0005959455996415986+3.445080782824864e-09j)
# (0.0006018745925935915+3.4786572493073177e-09j)
# (0.0006078425597231442+3.5124656318332115e-09j)
# (0.0006138502884410156+3.5465120921747633e-09j)
# (0.0006198985820647177+3.5808029361719667e-09j)
# (0.0006259882601397873+3.615345061836294e-09j)
# (0.0006321201587675437+3.6501451542629046e-09j)
# (0.0006382951309394639+3.6852104018087107e-09j)
# (0.0006445140468783071+3.720547956835583e-09j)
# (0.0006507777943861275+3.756165249259036e-09j)
# (0.0006570872791993104+3.792070152475673e-09j)
# (0.0006634434253507773+3.828270445284425e-09j)
# (0.0006698471755395022+3.8647744558624005e-09j)
# (0.0006762994915074865+3.901590665981896e-09j)
# (0.000682801354424344+3.9387277173389975e-09j)
# (0.0006893537652796488+3.9761948185259386e-09j)
# (0.0006959577452832025+4.014001218851275e-09j)
# (0.0007026143362733821+4.0521564127624215e-09j)
# (0.0007093246011337281+4.090670296074685e-09j)
# (0.0007160896242179422+4.129553050259942e-09j)
# (0.000722910511783463+4.168815419163984e-09j)
# (0.0007297883924337916+4.208468044055368e-09j)
# (0.0007367244175697457+4.248522408617976e-09j)
# (0.0007437197618498201+4.288989839206081e-09j)
# (0.0007507756236598381+4.329882444097778e-09j)
# (0.0007578932255920817+4.37121265895677e-09j)
# (0.0007650738149340897+4.412993172660871e-09j)
# (0.0007723186641673215+4.455237231214674e-09j)
# (0.0007796290714758821+4.497958318175862e-09j)
# (0.0007870063612655135+4.541170541407424e-09j)
# (0.0007944518846930595+4.5848885023586065e-09j)
# (0.0008019670202066121+4.629127089318206e-09j)
# (0.0008095531740965583+4.673901969048874e-09j)
# (0.0008172117810577445+4.7192292196414775e-09j)
# (0.0008249443047629841+4.7651252118512335e-09j)
# (0.0008327522384481354+4.811607179936484e-09j)
# (0.0008406371055089837+4.858692813477843e-09j)
# (0.0008486004601101654+4.906400310157711e-09j)
# (0.0008566438878063765+4.954748775045236e-09j)
# (0.0008647690061761126+5.003757519530083e-09j)
# (0.0008729774654681944+5.0534470317616486e-09j)
# (0.0008812709492613323+5.1038381730615765e-09j)
# (0.0008896511751369977+5.154952371873789e-09j)
# (0.0008981198953658662+5.206812033958641e-09j)
# (0.0009066788976081052+5.259440387369804e-09j)
# (0.0009153300056277869+5.3128613128640835e-09j)
# (0.0009240750800217092+5.367099488170943e-09j)
# (0.0009329160189629157+5.4221807302871795e-09j)
# (0.0009418547589592095+5.478131309548962e-09j)
# (0.000950893275626965+5.534978783803853e-09j)
# (0.0009600335844805423+5.592751460710169e-09j)
# (0.0009692777417376202+5.651478591986186e-09j)
# (0.0009786278451407685+5.7111907386828915e-09j)
# (0.000988086034795585+5.7719194132608396e-09j)
# (0.0009976544940257304+5.833697102419648e-09j)
# (0.0010073354502452044+5.8965575531392276e-09j)
# (0.001017131175848203+5.96053576005785e-09j)
# (0.0010270439891169188+6.025667758170767e-09j)
# (0.001037076255147638+6.091991101727141e-09j)
# (0.0010472303867955087+6.159544356405319e-09j)
# (0.0010575088456383484+6.228367706305019e-09j)
# (0.001067914142959881+6.298502891213054e-09j)
# (0.001078448840752789+6.369992798700549e-09j)
# (0.0010891155527419805+6.44288225652971e-09j)
# (0.0010999169454284777+6.517217240627563e-09j)
# (0.0011108557391543423+6.593045819755494e-09j)
# (0.001121934709189059+6.670417718340379e-09j)
# (0.0011331566868378073+6.749384152500862e-09j)
# (0.001144524560572065+6.829998594702228e-09j)
# (0.0011560412771829882+6.912316124450765e-09j)
# (0.001167709842958029+6.9963940180120135e-09j)
# (0.0011795333248812532+7.082291566739666e-09j)
# (0.0011915148518578374+7.170070221765666e-09j)
# (0.0012036576159632308+7.259793719016815e-09j)
# (0.0012159648737174753+7.351528171084872e-09j)
# (0.001228439947385189+7.445342111946263e-09j)
# (0.0012410862263017306+7.541306479980295e-09j)
# (0.0012539071682260666+7.639494968250997e-09j)
# (0.0012669063007208809+7.739983949176423e-09j)
# (0.0012800872225604697+7.842852623384765e-09j)
# (0.0012934536051669816+7.948182931688361e-09j)
# (0.0013070091940755723+8.056060322748687e-09j)
# (0.0013207578104290473+8.166572693558886e-09j)
# (0.001334703352502597+8.279811924563135e-09j)
# (0.0013488497972592097+8.39587310462279e-09j)
# (0.001363201201936394+8.514854755891785e-09j)
# (0.0013777617056648284+8.636859149012117e-09j)
# (0.0013925355311195811+8.761992353308907e-09j)
# (0.0014075269862045526+8.890364553952921e-09j)
# (0.0014227404657708043+9.022089834887355e-09j)
# (0.0014381804533694562+9.157286845804447e-09j)
# (0.001453851523039841+9.296078439799371e-09j)
# (0.0014697583411336246+9.438592253083494e-09j)
# (0.0014859056681756095+9.584960755377282e-09j)
# (0.0015022983607619594+9.735321407909192e-09j)
# (0.0015189413734965878+9.889816787642705e-09j)
# (0.0015358397609664817+1.0048594979227992e-08j)
# (0.0015529986797567313+1.0211809646756359e-08j)
# (0.001570423390506066+1.0379620417327868e-08j)
# (0.0015881192600037041+1.0552192874824839e-08j)
# (0.0016060917633283409+1.0729698904173188e-08j)
# (0.0016243464860301179+1.0912316903646275e-08j)
# (0.001642889126356435+1.110023226943702e-08j)
# (0.0016617254975224774+1.1293637333885484e-08j)
# (0.0016808615300273498+1.1492731824479257e-08j)
# (0.0017003032740167349+1.1697723132678155e-08j)
# (0.0017200569016929963+1.1908826679026315e-08j)
# (0.0017401287097736796+1.212626610405356e-08j)
# (0.0017605251219993724+1.2350273678665188e-08j)
# (0.0017812526916919107+1.2581090659590594e-08j)
# (0.0018023181043639357+1.2818967202335764e-08j)
# (0.001823728180380822+1.3064163662375607e-08j)
# (0.0018454898776760235+1.331695033909501e-08j)
# (0.001867610294520902+1.3577607710642383e-08j)
# (0.00189009667235012+1.3846427429065635e-08j)
# (0.0019129563986437059+1.4123712122110575e-08j)
# (0.001936197009866924+1.4409776264258111e-08j)
# (0.001959826194469095+1.4704946602080372e-08j)
# (0.0019838517959425346+1.5009562614538804e-08j)
# (0.002008281815942823+1.5323976930742422e-08j)
# (0.0020331244174716027+1.5648555735633987e-08j)
# (0.0020583879281231674+1.5983679634929025e-08j)
# (0.002084080843396095+1.6329744004004956e-08j)
# (0.002110211830071222+1.6687159840350394e-08j)
# (0.002136789729657282+1.7056353804084963e-08j)
# (0.002163823561905538+1.743776968003407e-08j)
# (0.0021913225283947922+1.783186805079618e-08j)
# (0.0022192960161881562+1.823912796060135e-08j)
# (0.002247753601563015+1.866004712904121e-08j)
# (0.0022767050538156286+1.9095142598432426e-08j)
# (0.002306160339141849+1.9544951584558135e-08j)
# (0.002336129624595468+2.001003285085592e-08j)
# (0.002366623282125722+2.0490966811759743e-08j)
# (0.002397651892695526+2.0988356673552053e-08j)
# (0.002429226250482033+2.1502829362986684e-08j)
# (0.002461357367161144+2.203503643167042e-08j)
# (0.002494056476277629+2.2585655229385595e-08j)
# (0.00252733503770255+2.3155389523273294e-08j)
# (0.0025612047421797093+2.3744971064984122e-08j)
# (0.0025956775159628746+2.4355160492732317e-08j)
# (0.0026307655255455795+2.4986748057816335e-08j)
# (0.002666481182485323+2.5640555768302838e-08j)
# (0.0027028371483240154+2.6317437650276296e-08j)
# (0.0027398463396065866+2.7018281702697436e-08j)
# (0.0027775219329996665+2.7744011118864567e-08j)
# (0.002815877370512327+2.8495585225649014e-08j)
# (0.0028549263648208712+2.9274001693397375e-08j)
# (0.0028946829046997352+3.008029778556887e-08j)
# (0.0029351612605605657+3.091555140556893e-08j)
# (0.0029763759901016095+3.1780883576631514e-08j)
# (0.0030183419440695802+3.267745965069205e-08j)
# (0.00306107427213619+3.3606491305698893e-08j)
# (0.0031045884288916116+3.4569238160180276e-08j)
# (0.003148900179957153+3.556701004306203e-08j)
# (0.0031940256082194653+3.660116872443698e-08j)
# (0.003239981120188682+3.767313023220903e-08j)
# (0.003286783452482887+3.8784366646336606e-08j)
# (0.0033344496784413953+3.993640891359404e-08j)
# (0.003382997214869352+4.113084832629171e-08j)
# (0.0034324438289162064+4.23693405111829e-08j)
# (0.003482807645090678+4.365360621199318e-08j)
# (0.0035341071524148575+4.498543501285324e-08j)
# (0.0035863612117201633+4.636668791967522e-08j)
# (0.0036395890630879003+4.7799300028841796e-08j)
# (0.00369381033343723+4.9285283495845367e-08j)
# (0.0037490450442634183+5.082673110940489e-08j)
# (0.003805313619529265+5.242581898132194e-08j)
# (0.0038626368937126824+5.4084809840269184e-08j)
# (0.003921036120013457+5.5806057398100454e-08j)
# (0.003980532978722253+5.759200879427386e-08j)
# (0.0040411495857550035+5.944520909633418e-08j)
# (0.004102908501355879+6.136830548311177e-08j)
# (0.004165832738972075+6.33640506007388e-08j)
# (0.00422994577430374+6.543530722133952e-08j)
# (0.004295271554532405+6.758505275559305e-08j)
# (0.00436183450773134+6.981638358687414e-08j)
# (0.004429659552461341+7.213252027680912e-08j)
# (0.004498772107555506+7.453681210966204e-08j)
# (0.004569198102096592+7.70327425212402e-08j)
# (0.0046409639855906825+7.962393470619221e-08j)
# (0.00471409673834087+8.231415655383406e-08j)
# (0.004788623882024814+8.510732735934947e-08j)
# (0.004864573490480022+8.80075230597446e-08j)
# (0.004941974200700846+9.101898347949005e-08j)
# (0.005020855224051183+9.41461180383052e-08j)
# (0.005101246357697019+9.739351299498797e-08j)
# (0.005183177996262939+1.007659388192014e-07j)
# (0.005266681143716884+1.042683572392022e-07j)
# (0.005351787425487446+1.07905928801282e-07j)
# (0.005438529100818118+1.1168402150810883e-07j)
# (0.005526939075362934+1.156082183905219e-07j)
# (0.0056170509140280826+1.196843268129778e-07j)
# (0.005708898854064087+1.2391838737595138e-07j)
# (0.005802517818413282+1.2831668299969286e-07j)
# (0.0058979434293173405+1.3288574893970029e-07j)
# (0.005995212022189753+1.3763238287113652e-07j)
# (0.006094360659758189+1.4256365545088556e-07j)
# (0.006195427146481768+1.4768692136965703e-07j)
# (0.006298450043248369+1.5300983072960235e-07j)
# (0.006403468682357187+1.5854034129166612e-07j)
# (0.006510523182791809+1.6428673006755317e-07j)
# (0.006619654465789206+1.702576068759911e-07j)
# (0.006730904270710095+1.764619276322924e-07j)
# (0.006844315171216246+1.8290900783587817e-07j)
# (0.006959930591760363+1.896085376368782e-07j)
# (0.007077794824394292+1.9657059644574692e-07j)
# (0.007197953045901385+2.0380566917932787e-07j)
# (0.007320451335258957+2.113246615916219e-07j)
# (0.007445336691436848+2.1913891814707778e-07j)
# (0.007572657051538205+2.2726023957646114e-07j)
# (0.007702461309288721+2.3570090059228957e-07j)
# (0.00783479933388062+2.4447366946500895e-07j)
# (0.007969721989177808+2.535918278281673e-07j)
# (0.008107281153288725+2.630691911842939e-07j)
# (0.008247529738513452+2.7292013035045674e-07j)
# (0.008390521711671851+2.8315959384486995e-07j)
# (0.008536312114819524+2.938031310841769e-07j)
# (0.008684957086358485+3.0486691690231284e-07j)
# (0.008836513882549588+3.163677757609928e-07j)
# (0.008991040899433877+3.2832320898158446e-07j)
# (0.009148597695169989+3.4075142095908804e-07j)
# (0.009309245012795028+3.5367134793092143e-07j)
# (0.009473044803416321+3.671026870463091e-07j)
# (0.0096400602498416+3.810659274180599e-07j)
# (0.009810355790655248+3.9558238110812456e-07j)
# (0.009983997144748402+4.106742171418742e-07j)
# (0.010161051336310763+4.26364494903749e-07j)
# (0.010341586720292055+4.426772002842169e-07j)
# (0.010525673008341287+4.5963728307717544e-07j)
# (0.010713381295231918+4.772706951338039e-07j)
# (0.010904784085781306+4.956044306641312e-07j)
# (0.01109995532227279+5.146665681812107e-07j)
# (0.011298970412388922+5.344863138962937e-07j)
# (0.011501906257664504+5.550940465682204e-07j)
# (0.011708841282468112+5.765213645494005e-07j)
# (0.011919855463520989+5.988011351688265e-07j)
# (0.012135030359962162+6.219675445365444e-07j)
# (0.01235444914396895+6.460561508923809e-07j)
# (0.012578196631941896+6.711039393255675e-07j)
# (0.012806359316263446+6.971493787091253e-07j)
# (0.013039025397639702+7.24232481147054e-07j)
# (0.013276284818034719+7.523948635626067e-07j)
# (0.013518229294206886+7.816798112621797e-07j)
# (0.013764952351857077+8.121323457217308e-07j)
# (0.014016549360398294+8.43799292695064e-07j)
# (0.014273117568356667+8.767293545679978e-07j)
# (0.014534756139413775+9.10973185149072e-07j)
# (0.01480156618910026+9.465834675554509e-07j)
# (0.015073650822150942+9.836149947501666e-07j)
# (0.015351115170531579+1.02212475394627e-06j)
# (0.015634066432147598+1.0621720135156332e-06j)
# (0.015922613910245176+1.1038184141077424e-06j)
# (0.016216869053515118+1.1471280627383291e-06j)
# (0.016516945496910032+1.1921676306409336e-06j)
# (0.016822959103185486+1.2390064555753335e-06j)
# (0.017135028005175718+1.2877166472866621e-06j)
# (0.0174532726488147+1.3383731981111468e-06j)
# (0.017777815836913305+1.3910540963503227e-06j)
# (0.018108782773703463+1.4458404458484099e-06j)
# (0.018446301110160157+1.5028165891249517e-06j)
# (0.018790500990112237+1.5620702359597489e-06j)
# (0.019141515097152985+1.623692595972155e-06j)
# (0.019499478702361524+1.6877785176790854e-06j)
# (0.019864529712845976+1.7544266322213438e-06j)
# (0.020236808721119586+1.8237395025064562e-06j)
# (0.020616459055320727+1.8958237790528046e-06j)
# (0.021003626830287978+1.9707903608814966e-06j)
# (0.02139846099950128+2.048754563058546e-06j)
# (0.021801113407900263+2.1298362906037906e-06j)
# (0.022211738845590783+2.2141602197868865e-06j)
# (0.02263049510245065+2.3018559854426825e-06j)
# (0.02305754302364558+2.393058376172217e-06j)
# (0.023493046566066267+2.487907536952324e-06j)
# (0.023937172855697426+2.5865491794023355e-06j)
# (0.02439009224592965+2.6891348004249186e-06j)
# (0.02485197837682476+2.795821908705877e-06j)
# (0.025323008235345293+2.906774260615877e-06j)
# (0.025803362216558656+3.02216210452708e-06j)
# (0.02629322418582632+3.142162435423269e-06j)
# (0.026792781541988317+3.266959257849379e-06j)
# (0.027302225281553186+3.396743860250842e-06j)
# (0.027821750063903302+3.5317150988311163e-06j)
# (0.028351554277525354+3.672079692975245e-06j)
# (0.028891840107275534+3.818052531272343e-06j)
# (0.029442813602688866+3.969856989329735e-06j)
# (0.03000468474734169+4.127725260347998e-06j)
# (0.030577667529276313+4.291898696934695e-06j)
# (0.031161980012496322+4.462628166642795e-06j)
# (0.03175784440954094+4.640174421566776e-06j)
# (0.03236548715514639+4.824808480237591e-06j)
# (0.03298513898100194+5.016812025234607e-06j)
# (0.03361703499160796+5.216477815067388e-06j)
# (0.03426141474124296+5.424110112164227e-06j)
# (0.034918522312045924+5.640025125937606e-06j)
# (0.0355886063932203+5.864551473170184e-06j)
# (0.03627192036136506+6.0980306550876914e-06j)
# (0.03696872236193813+6.3408175530864244e-06j)
# (0.03767927539185652+6.593280941410566e-06j)
# (0.038403847383237606+6.855804020210589e-06j)
# (0.039142711288284796+7.128784967504234e-06j)
# (0.039896145165320404+7.412637511907556e-06j)
# (0.04066443226596822+7.707791526164178e-06j)
# (0.04144786112348699+8.01469364305944e-06j)
# (0.04224672564225599+8.333807893101298e-06j)
# (0.043061325188412394+8.665616366544676e-06j)
# (0.04389196468164007+9.01061989855062e-06j)
# (0.044738954688107915+9.369338780208637e-06j)
# (0.04560261151455562+9.742313494558e-06j)
# (0.04648325730352324+1.0130105480310568e-05j)
# (0.04738122012972048+1.0533297921798279e-05j)
# (0.04829683409753021+1.0952496568977966e-05j)
# (0.04923043943964005+1.1388330585662123e-05j)
# (0.05018238261679429+1.1841453429202909e-05j)
# (0.051153016418657805+1.2312543760488215e-05j)
# (0.052142700065782+1.280230638768432e-05j)
# (0.053151799312661605+1.3311473241878568e-05j)
# (0.05418068655187034+1.3840804388970998e-05j)
# (0.05522974091926121+1.4391089076979356e-05j)
# (0.05629934840021664+1.496314681874753e-05j)
# (0.05738990193693165+1.5557828514614507e-05j)
# (0.05850180153671199+1.6176017613629406e-05j)
# (0.05963545438126734+1.6818631314783874e-05j)
# (0.06079127493697818+1.7486621810300923e-05j)
# (0.061969685066113375+1.8180977572332717e-05j)
# (0.06317111413897314+1.8902724683778856e-05j)
# (0.0643959991469309+1.965292821436234e-05j)
# (0.06564478481634517+2.0432693644789454e-05j)
# (0.06691792372331071+2.1243168338621742e-05j)
# (0.06821587640921621+2.2085543064524156e-05j)
# (0.06953911149707345+2.296105356962943e-05j)
# (0.07088810580858088+2.387098220651187e-05j)
# (0.072263344481882+2.4816659613836202e-05j)
# (0.07366532108997705+2.5799466454148247e-05j)
# (0.07509453775974312+2.6820835208280985e-05j)
# (0.07655150529151661+2.7882252029792657e-05j)
# (0.07803674327918786+2.8985258659982977e-05j)
# (0.07955078023075651+3.0131454406150318e-05j)
# (0.0810941536892923+3.132249818324942e-05j)
# (0.08266741035424352+3.2560110623003034e-05j)
# (0.08427110620303281+3.3846076249644966e-05j)
# (0.0859058066128762+3.518224572608741e-05j)
# (0.08757208648275867+3.657053817135613e-05j)
# (0.08927053035549651+3.801294355195078e-05j)
# (0.09100173253981254+3.9511525147292244e-05j)
# (0.09276629723234817+4.106842209315186e-05j)
# (0.0945648386395317+4.2685852003784685e-05j)
# (0.09639798109921943+4.436611367487897e-05j)
# (0.09826635920202216+4.611158987011332e-05j)
# (0.10017061791222591+4.7924750190704015e-05j)
# (0.10211141268821244+4.980815403393465e-05j)
# (0.1040894096022804+5.176445363835818e-05j)
# (0.10610528545976454+5.379639722100523e-05j)
# (0.10815972791734643+5.5906832206046333e-05j)
# (0.11025343560044572+5.809870854930981e-05j)
# (0.11238711821957652+6.037508215805975e-05j)
# (0.11456149668555012+6.273911840956076e-05j)
# (0.11677730322339983+6.519409577048036e-05j)
# (0.11903528148490011+6.774340951787417e-05j)
# (0.12133618665954694+7.039057556434703e-05j)
# (0.12368078558386257+7.313923438928976e-05j)
# (0.12606985684888275+7.599315507869103e-05j)
# (0.12850419090567952+7.895623947252617e-05j)
# (0.13098459016876873+8.203252642565933e-05j)
# (0.13351186911724625+8.522619618016703e-05j)
# (0.13608685439349133+8.85415748529822e-05j)
# (0.13871038489927215+9.198313903911464e-05j)
# (0.1413833118890827+9.555552053333722e-05j)
# (0.144106499060535+9.92635111701578e-05j)
# (0.14688082264162677+0.00010311206778457798j)
# (0.14970717147469878+0.00010710631729392878j)
# (0.15258644709689156+0.0001112515619034683j)
# (0.1555195638169063+0.00011555328443476265j)
# (0.15850744878786943+0.00012001715377914518j)
# (0.16155104207609622+0.00012464903047641534j)
# (0.1646512967255429+0.00012945497241999466j)
# (0.16780917881773286+0.00013444124068779555j)
# (0.17102566752693762+0.00013961430550115455j)
# (0.17430175517038776+0.00014498085230934006j)
# (0.17763844725328562+0.00015054778800226504j)
# (0.18103676250838627+0.00015632224724910975j)
# (0.1844977329299091+0.00016231159896338315j)
# (0.1880224038015381+0.00016852345289403975j)
# (0.19161183371826518+0.00017496566634113658j)
# (0.19526709460182623+0.00018164635099466114j)
# (0.19898927170947575+0.00018857387989561032j)
# (0.20277946363584437+0.0001957568945185793j)
# (0.20663878230761648+0.0002032043119717815j)
# (0.2105683529707657+0.00021092533231390926j)
# (0.21456931417008082+0.00021892944598478855j)
# (0.2186428177207131+0.0002272264413469584j)
# (0.22279002867147257+0.00023582641233454331j)
# (0.2270121252596009+0.0002447397662065381j)
# (0.23131029885674395+0.00025397723140004145j)
# (0.23568575390584798+0.000263549865479275j)
# (0.24013970784870164+0.0002734690631752617j)
# (0.2446733910438452+0.0002837465645115303j)
# (0.24928804667456833+0.00029439446301068433j)
# (0.25398493064671845+0.00030542521397350814j)
# (0.2587653114760416+0.000316851642827321j)
# (0.26363047016477953+0.00032868695353374785j)
# (0.26858170006724874+0.00034094473705048616j)
# (0.27362030674412874+0.0003536389798380149j)
# (0.27874760780518953+0.00036678407240267147j)
# (0.2839649327401927+0.0003803948178676698j)
# (0.2892736227377037+0.0003944864405627609j)
# (0.2946750304915574+0.00040907459462080924j)
# (0.30017051999472516+0.0004241753725727598j)
# (0.3057614663203367+0.00043980531392852525j)
# (0.31144925538961643+0.00045598141373196915j)
# (0.3172352837265034+0.00047272113107843213j)
# (0.3231209581987288+0.0004900423975806015j)
# (0.3291076957451375+0.0005079636257706168j)
# (0.3351969230890458+0.0005265037174236998j)
# (0.34139007643744124+0.0005456820717873232j)
# (0.3476886011658406+0.0005655185937030683j)
# (0.35409395148863326+0.000586033701603448j)
# (0.36060759011475035+0.0006072483353675236j)
# (0.36723098788851594+0.00062918396401853j)
# (0.37396562341554745+0.0006518625932461844j)
# (0.380812982673591+0.0006753067727346049j)
# (0.38777455860819243+0.0006995396032778037j)
# (0.3948518507131218+0.0007245847436635897j)
# (0.4020463645954878+0.00075046641730515j)
# (0.4093596115254976+0.0007772094186015502j)
# (0.41679310797083613+0.0008048391190048665j)
# (0.42434837511566126+0.0008333814727737361j)
# (0.43202693836423195+0.0008628630223912508j)
# (0.4398303268292087+0.0008933109036263252j)
# (0.44776007280468844+0.0009247528502139695j)
# (0.45581771122406256+0.0009572171981346467j)
# (0.46400477910280696+0.000990732889466833j)
# (0.47232281496634326+0.0010253294757930635j)
# (0.48077335826313283+0.001061037121132561j)
# (0.4893579487631953+0.0010978866043793755j)
# (0.4980781259422682+0.0011359093212229897j)
# (0.5069354283518533+0.001175137285524839j)
# (0.5159313929754263+0.0012156031301305864j)
# (0.5250675545711115+0.0012573401070931848j)
# (0.5343454450011558+0.0013003820872832515j)
# (0.5437665925485671+0.0013447635593648018j)
# (0.5533325212213084+0.0013905196281123276j)
# (0.5630447500444761+0.001437686012048731j)
# (0.5729047923409141+0.0014862990403802846j)
# (0.5829141550007548+0.0015363956492084492j)
# (0.593074337740402+0.0015880133769975993j)
# (0.6033868323515039+0.0016411903592789903j)
# (0.6138531219405021+0.001695965322570231j)
# (0.6244746801593577+0.00175237757749458j)
# (0.6352529704281058+0.0018104670110785015j)
# (0.6461894451499018+0.0018702740782165106j)
# (0.6572855449192664+0.0019318397922815718j)
# (0.6685426977242541+0.0019952057148732495j)
# (0.6799623181433089+0.0020604139446851583j)
# (0.691545806537589+0.002127507105484339j)
# (0.7032945482395775+0.002196528333189723j)
# (0.7152099127388138+0.0022675212620432666j)
# (0.7272932528656134+0.002340530009865178j)
# (0.7395459039736602+0.002415599162388235j)
# (0.7519691831223829+0.00249277375666834j)
# (0.7645643882600461+0.0025720992635699185j)
# (0.7773327974085054+0.0026536215693241214j)
# (0.7902756678505946+0.0027373869561655314j)
# (0.803394235321132+0.002823442082047783j)
# (0.816689713202542+0.0029118339594478597j)
# (0.8301632917261059+0.0030026099332638987j)
# (0.8438161371798638+0.0030958176578210718j)
# (0.857649391124201+0.00319150507299378j)
# (0.8716641696161557+0.003289720379463635j)
# (0.885861562443492+0.0033905120131267194j)
# (0.9002426323695851+0.0034939286186718823j)
# (0.9148084143901635+0.0036000190223510844j)
# (0.9295599150029522+0.003708832203966182j)
# (0.9444981114912586+0.0038204172680972536j)
# (0.9596239512225313+0.0039348234146032775j)
# (0.9749383509629177+0.004052099908423813j)
# (0.990442196208831+0.0041722960487164465j)
# (1.0061363405365262+0.00429546113736399j)
# (1.0220216049706654+0.004421644446889189j)
# (1.0380987773728343+0.004550895187816648j)
# (1.054368611850955+0.004683262475523128j)
# (1.0708318281905054+0.004818795296618921j)
# (1.0874891113084448+0.004957542474906502j)
# (1.1043411107307017+0.005099552636962834j)
# (1.121388440094059+0.005244874177393415j)
# (1.1386316766732338+0.005393555223808664j)
# (1.156071360933918+0.005545643601574446j)
# (1.1737079961125019+0.005701186798388248j)
# (1.191542047823173+0.0058602319287364745j)
# (1.2095739436930306+0.006022825698286728j)
# (1.2278040730258224+0.0061890143682709325j)
# (1.2462327864948628+0.006358843719917669j)
# (1.2648603958656384+0.00653235901898771j)
# (1.2836871737485729+0.006709604980473652j)
# (1.3027133533823614+0.006890625733519442j)
# (1.32193912844824+0.007075464786618578j)
# (1.3413646529155046+0.007264164993149777j)
# (1.3609900409185425+0.007456768517305673j)
# (1.3808153666655805+0.00765331680047489j)
# (1.4008406643793097+0.007853850528131416j)
# (1.421065928269483+0.008058409597290254j)
# (1.441491112537537+0.008267033084581887j)
# (1.4621161314132252+0.008479759215002406j)
# (1.4829408592232034+0.008696625331390902j)
# (1.5039651304914528+0.008917667864685517j)
# (1.5251887400713628+0.009142922305010093j)
# (1.546611443309259+0.009372423173637704j)
# (1.5682329562390924+0.009606203995880722j)
# (1.5900529558079666+0.009844297274949563j)
# (1.6120710801321199+0.010086734466824645j)
# (1.6342869287829336+0.010333545956182119j)
# (1.6567000631024904+0.010584761033411324j)
# (1.6793100065481548+0.010840407872760163j)
# (1.702116245065606+0.011100513511642573j)
# (1.725118227489707+0.011365103831138193j)
# (1.748315365972552+0.01163420353771403j)
# (1.7717070364379952+0.011907836146191422j)
# (1.7952925790619187+0.012186023963985368j)
# (1.819071298777475+0.012468788076631182j)
# (1.8430424658044833+0.012756148334620817j)
# (1.8672053162021491+0.013048123341559685j)
# (1.8915590524442312+0.013344730443657951j)
# (1.9161028440157566+0.01364598572056313j)
# (1.9408358280303617+0.01395190397754164j)
# (1.9657571098673097+0.014262498739011146j)
# (1.9908657638272176+0.014577782243424159j)
# (2.0161608338055044+0.014897765439499935j)
# (2.0416413339825614+0.0152224579838005j)
# (2.0673062495296266+0.015551868239640347j)
# (2.093154537329335+0.015886003277321703j)
# (2.1191851267099127+0.016224868875679706j)
# (2.1453969201919767+0.016568469524923416j)
# (2.171788794246884+0.01691680843075252j)
# (2.198359600065597+0.017269887519730916j)
# (2.2251081643370125+0.017627707445893252j)
# (2.2520332900347126+0.017990267598559057j)
# (2.2791337572111035+0.0183575661113285j)
# (2.3064083237979105+0.018729599872229608j)
# (2.333855726412008+0.01910636453498731j)
# (2.3614746811655825+0.019487854531380265j)
# (2.38926388447962+0.019874063084652605j)
# (2.4172220138997567+0.020264982223945224j)
# (2.4453477289135117+0.02066060279970838j)
# (2.4736396717679674+0.021060914500058144j)
# (2.5020964682869704+0.02146590586803888j)
# (2.5307167286869476+0.02187556431974917j)
# (2.55949904839046+0.022289876163291956j)
# (2.5884420088366342+0.022708826618506883j)
# (2.617544178287643+0.023132399837442513j)
# (2.646804112630426+0.023560578925525405j)
# (2.676220356172877+0.023993345963383903j)
# (2.7057914424337435+0.02443068202928146j)
# (2.7355158949255163+0.024872567222119942j)
# (2.7653922279296195+0.025318980684963955j)
# (2.795418947263237+0.025769900629048523j)
# (2.8255945510371405+0.02622530435822336j)
# (2.855917530403919+0.026685168293792735j)
# (2.886386370296041+0.027149467999707324j)
# (2.916999550153205+0.02761817820806805j)
# (2.94775554463847+0.028091272844898308j)
# (2.9786528243426895+0.02856872505614629j)
# (3.009689856476803+0.029050507233875887j)
# (3.040865105551565+0.029536591042607363j)
# (3.072177034044328+0.030026947445770367j)
# (3.10362410305253+0.030521546732231387j)
# (3.135204772933546+0.03102035854285901j)
# (3.1669175039306285+0.03152335189709295j)
# (3.198760756784653+0.03203049521948164j)
# (3.230732993331441+0.03254175636615467j)
# (3.2628326770844436+0.033057102651200876j)
# (3.295058273802613+0.03357650087291776j)
# (3.327408252043292+0.03409991733990563j)
# (3.3598810837000093+0.03462731789697689j)
# (3.392475244525057+0.03515866795085359j)
# (3.425189214636788+0.0356939324956273j)
# (3.4580214790115646+0.03623307613795794j)
# (3.490970527960335+0.03677606312198612j)
# (3.5240348575898155+0.03732285735393955j)
# (3.5572129702483006+0.03787342242641126j)
# (3.590503374956125+0.038427721642290705j)
# (3.6239045878208263+0.038985718038329564j)
# (3.657415132437086+0.03954737440832538j)
# (3.6910335402715244+0.04011265332590746j)
# (3.7247583510324644+0.04068151716691014j)
# (3.7585881130247736+0.04125392813132125j)
# (3.7925213834899294+0.04182984826479134j)
# (3.8265567289314495+0.04240923947969684j)
# (3.8606927254258583+0.04299206357574187j)
# (3.8949279589193524+0.04357828226009527j)
# (3.929261025510372+0.04416785716705113j)
# (3.963690531718253+0.04476074987720954j)
# (3.998215094738193+0.04535692193616829j)
# (4.032833342682728+0.0459563348727242j)
# (4.067543914809963+0.04655895021657818j)
# (4.1023454617387785+0.04716472951554262j)
# (4.137236645651271+0.04777363435224776j)
# (4.172216140482649+0.04838562636034673j)
# (4.20728263209887+0.049000667240219085j)
# (4.242434818462257+0.04961871877417228j)
# (4.277671409785362+0.05023974284114339j)
# (4.312991128673349+0.05086370143090243j)
# (4.348392710255163+0.05149055665775842j)
# (4.383874902303759+0.05212027077377435j)
# (4.419436465345668+0.05275280618149109j)
# (4.455076172760173+0.053388125446167736j)
# (4.4907928108683794+0.05402619130753951j)
# (4.526585179012449+0.054666966691103526j)
# (4.5624520896252925+0.05531041471893182j)
# (4.598392368290976+0.05595649872002318j)
# (4.634404853796141+0.056605182240196956j)
# (4.670488398172703+0.0572564290515364j)
# (4.7066418667321015+0.057910203161390415j)
# (4.742864138091389+0.058566468820938244j)
# (4.779154104191409+0.059225190533325874j)
# (4.815510670307358+0.0598863330613844j)
# (4.851932755051963+0.060549861434934384j)
# (4.888419290371578+0.061215740957688364j)
# (4.924969221535427+0.06188393721375682j)
# (4.961581507118261+0.06255441607376949j)
# (4.998255118976688+0.06322714370061822j)
# (5.034989042219418+0.06390208655483053j)
# (5.071782275171663+0.06457921139958485j)
# (5.108633829333948+0.06525848530537416j)
# (5.1455427293355545+0.06593987565432873j)
# (5.182508012882831+0.06662335014420522j)
# (5.219528730702613+0.06730887679205404j)
# (5.256603946480947+0.0679964239375709j)
# (5.29373273679737+0.0686859602461442j)
# (5.330914191054928+0.06937745471160624j)
# (5.368147411406158+0.07007087665869625j)
# (5.405431512675238+0.07076619574524694j)
# (5.442765622276501+0.07146338196410063j)
# (5.480148880129494+0.07216240564476518j)
# (5.517580438570798+0.07286323745481829j)
# (5.555059462262764+0.0735658484010689j)
# (5.592585128099368+0.07427020983048326j)
# (5.630156625109341+0.07497629343088606j)
# (5.667773154356752+0.07568407123144227j)
# (5.705433928839211+0.07639351560293033j)
# (5.7431381733838425+0.07710459925781261j)
# (5.7808851245411885+0.07781729525011355j)
# (5.818674030477196+0.07853157697510975j)
# (5.8565041508634215+0.07924741816884284j)
# (5.894374756765609+0.0799647929074616j)
# (5.932285130530762+0.08068367560639912j)
# (5.970234565672847+0.0814040410193943j)
# (6.008222366757264+0.08212586423736334j)
# (6.046247849284188+0.08284912068712863j)
# (6.084310339570919+0.08357378613001144j)
# (6.1224091746333364+0.0842998366602948j)
# (6.160543702066577+0.0850272487035636j)
# (6.198713279925051+0.08575599901492707j)
# (6.236917276601872+0.0864860646771306j)
# (6.27515507070783+0.087217423098562j)
# (6.3134260509499684+0.08795005201115867j)
# (6.351729616009885+0.08868392946822053j)
# (6.390065174421824+0.08941903384213355j)
# (6.428432144450644+0.09015534382201221j)
# (6.466829953969753+0.0908928384112609j)
# (6.505258040339068+0.0916314969250638j)
# (6.543715850283087+0.09237129898780512j)
# (6.582202839769137+0.09311222453042572j)
# (6.620718473885853+0.0938542537877202j)
# (6.65926222672198+0.0945973672955782j)
# (6.697833581245516+0.09534154588817537j)
# (6.736432029183297+0.09608677069511613j)
# (6.775057070901043+0.09683302313853413j)
# (6.813708215283933+0.09758028493015264j)
# (6.852384979617761+0.09832853806830938j)
# (6.891086889470705+0.09907776483494851j)
# (6.929813478575764+0.09982794779258404j)
# (6.968564288713904+0.10057906978123668j)
# (7.007338869597941+0.10133111391534863j)
# (7.046136778757216+0.10208406358067786j)
# (7.08495758142307+0.10283790243117603j)
# (7.123800850415182+0.10359261438585161j)
# (7.162666166028782+0.10434818362562151j)
# (7.201553115922758+0.10510459459015394j)
# (7.240461295008711+0.10586183197470389j)
# (7.279390305340958+0.10661988072694499j)
# (7.3183397560075205+0.10737872604379825j)
# (7.357309263022106+0.10813835336826125j)
# (7.396298449217118+0.10889874838623935j)
# (7.4353069441376975+0.10965989702337987j)
# (7.474334383936822+0.11042178544191265j)
# (7.513380411271473+0.1111844000374975j)
# (7.552444675199883+0.11194772743608061j)
# (7.591526831079886+0.11271175449076216j)
# (7.630626540468356+0.11347646827867443j)
# (7.669743471021778+0.11424185609787484j)
# (7.708877296397934+0.11500790546425316j)
# (7.748027696158715+0.11577460410845407j)
# (7.787194355674079+0.11654193997281788j)
# (7.826376966027142+0.11730990120833924j)
# (7.865575223920418+0.11807847617164453j)
# (7.904788831583205+0.11884765342199069j)
# (7.94401749668013+0.11961742171828431j)
# (7.98326093222083+0.12038777001612294j)
# (8.022518856470803+0.12115868746486062j)
# (8.061790992863399+0.12193016340469492j)
# (8.101077069912968+0.12270218736378025j)
# (8.140376821129152+0.12347474905536546j)
# (8.179689984932336+0.12424783837495683j)
# (8.219016304570227+0.12502144539750834j)
# (8.258355528035583+0.1257955603746368j)
# (8.297707407985081+0.12657017373186613j)
# (8.337071701659305+0.12734527606589854j)
# (8.376448170803869+0.12812085814191293j)
# (8.415836581591664+0.12889691089089308j)
# (8.455236704546202+0.1296734254069836j)
# (8.494648314466083+0.13045039294487465j)
# (8.534071190350565+0.13122780491721742j)
# (8.57350511532621+0.13200565289206684j)
# (8.612949876574628+0.13278392859035554j)
# (8.652405265261295+0.13356262388339707j)
# (8.691871076465441+0.13434173079041872j)
# (8.731347109110992+0.135121241476125j)
# (8.77083316589857+0.13590114824829094j)
# (8.810329053238535+0.13668144355538508j)
# (8.849834581185048+0.13746211998422309j)
# (8.889349563371175+0.13824317025765195j)
# (8.928873816944979+0.1390245872322635j)
# (8.968407162506642+0.13980636389613785j)
# (9.00794942404656+0.14058849336661872j)
# (9.047500428884424+0.14137096888811665j)
# (9.087060007609285+0.14215378382994345j)
# (9.12662799402056+0.14293693168417557j)
# (9.166204225069997+0.1437204060635484j)
# (9.205788540804594+0.14450420069937897j)
# (9.245380784310422+0.14528830943951845j)
# (9.284980801657385+0.14607272624633433j)
# (9.324588441844872+0.14685744519472121j)
# (9.364203556748318+0.14764246047014062j)
# (9.40382600106665+0.14842776636669003j)
# (9.443455632270583+0.1492133572851998j)
# (9.48309231055182+0.1499992277313585j)
# (9.522735898773064+0.15078537231386682j)
# (9.562386262418896+0.15157178574261926j)
# (9.602043269547465+0.1523584628269131j)
# (9.641706790743013+0.15314539847368475j)
# (9.681376699069203+0.15393258768577406j)
# (9.721052870023222+0.15472002556021472j)
# (9.760735181490706+0.15550770728655142j)
# (9.80042351370141+0.15629562814518405j)
# (9.840117749185664+0.15708378350573754j)
# (9.879817772731549+0.15787216882545757j)
# (9.919523471342856+0.1586607796476317j)
# (9.95923473419775+0.15944961160003632j)
# (9.998951452608154+0.16023866039340828j)
# (10.03867351997986+0.16102792181994174j)
# (10.078400831773324+0.16181739175180843j)
# (10.118133285465158+0.1626070661397036j)
# (10.157870780510295+0.16339694101141425j)
# (10.197613218304829+0.1641870124704123j)
# (10.23736050214951+0.1649772766944705j)
# (10.277112537213887+0.16576772993430125j)
# (10.31686923050109+0.16655836851221884j)
# (10.356630490813242+0.16734918882082278j)
# (10.39639622871748+0.16814018732170485j)
# (10.436166356512608+0.168931360544177j)
# (10.475940788196317+0.1697227050840213j)
# (10.51571943943302+0.17051421760226038j)
# (10.555502227522263+0.1713058948239507j)
# (10.595289071367695+0.1720977335369941j)
# (10.63507989144661+0.17288973059097143j)
# (10.674874609780044+0.17368188289599587j)
# (10.7146731499034+0.174474187421586j)
# (10.754475436837632+0.17526664119555824j)
# (10.794281397060939+0.17605924130293937j)
# (10.834090958480969+0.17685198488489706j)
# (10.873904050407551+0.17764486913768923j)
# (10.91372060352592+0.1784378913116328j)
# (10.953540549870427+0.17923104871008966j)
# (10.993363822798733+0.1800243386884709j)
# (11.033190356966498+0.1808177586532582j)
# (11.073020088302508+0.1816113060610436j)
# (11.112852953984284+0.18240497841758485j)
# (11.152688892414131+0.18319877327687956j)
# (11.19252784319564+0.18399268824025344j)
# (11.232369747110614+0.18478672095546733j)
# (11.272214546096434+0.18558086911583843j)
# (11.31206218322384+0.18637513045937798j)
# (11.351912602675137+0.18716950276794533j)
# (11.391765749722783+0.1879639838664152j)
# (11.43162157070841+0.18875857162186202j)
# (11.47148001302221+0.18955326394275834j)
# (11.51134102508272+0.19034805877818758j)
# (11.551204556316991+0.19114295411707125j)
# (11.591070557141109+0.19193794798741012j)
# (11.630938978941112+0.19273303845553974j)
# (11.67080977405423+0.19352822362539868j)
# (11.710682895750523+0.19432350163781167j)
# (11.750558298214814+0.19511887066978398j)
# (11.79043593652901+0.19591432893381033j)
# (11.830315766654719+0.1967098746771959j)
# (11.870197745416231+0.19750550618138965j)
# (11.910081830483788+0.19830122176133022j)
# (11.949967980357194+0.19909701976480448j)
# (11.989856154349722+0.19989289857181655j)
# (12.029746312572343+0.20068885659396987j)
# (12.069638415918233+0.20148489227386046j)
# (12.10953242604759+0.2022810040844805j)
# (12.149428305372739+0.20307719052863463j)
# (12.189326017043511+0.20387345013836558j)
# (12.229225524932911+0.20466978147439172j)
# (12.269126793623052+0.20546618312555423j)
# (12.309029788391365+0.20626265370827532j)
# (12.348934475197066+0.20705919186602598j)
# (12.388840820667882+0.20785579626880435j)
# (12.428748792087035+0.20865246561262352j)
# (12.468658357380477+0.2094491986190086j)
# (12.508569485104353+0.2102459940345041j)
# (12.548482144432729+0.21104285063018993j)
# (12.58839630514554+0.21183976720120706j)
# (12.62831193761677+0.21263674256629123j)
# (12.668229012802868+0.21343377556731663j)
# (12.708147502231364+0.21423086506884753j)
# (12.748067377989742+0.21502800995769814j)
# (12.787988612714484+0.21582520914250186j)
# (12.827911179580365+0.21662246155328732j)
# (12.867835052289927+0.21741976614106365j)
# (12.90776020506315+0.21821712187741316j)
# (12.947686612627363+0.21901452775409155j)
# (12.987614250207304+0.21981198278263606j)
# (13.027543093515392+0.22060948599398092j)
# (13.067473118742196+0.2214070364380804j)
# (13.107404302547067+0.22220463318353867j)
# (13.147336622048966+0.22300227531724667j)
# (13.187270054817466+0.22379996194402674j)
# (13.227204578863923+0.22459769218628275j)
# (13.267140172632828+0.2253954651836584j)
# (13.307076814993316+0.22619328009270073j)
# (13.347014485230847+0.22699113608653074j)
# (13.386953163039047+0.22778903235452028j)
# (13.426892828511697+0.22858696810197526j)
# (13.466833462134897+0.22938494254982453j)
# (13.506775044779367+0.23018295493431518j)
# (13.546717557692897+0.23098100450671322j)
# (13.586660982492958+0.23177909053301052j)
# (13.626605301159438+0.23257721229363731j)
# (13.666550496027533+0.23337536908317993j)
# (13.706496549780768+0.2341735602101039j)
# (13.746443445444164+0.2349717849964829j)
# (13.786391166377523+0.23577004277773264j)
# (13.826339696268859+0.23656833290234977j)
# (13.866289019127942+0.23736665473165633j)
# (13.906239119279986+0.23816500763954837j)
# (13.946189981359442+0.23896339101224984j)
# (13.986141590303918+0.23976180424807142j)
# (14.026093931348232+0.24056024675717386j)
# (14.066046990018553+0.2413587179613357j)
# (14.106000752126683+0.24215721729372586j)
# (14.145955203764428+0.24295574419868002j)
# (14.185910331298107+0.24375429813148236j)
# (14.225866121363135+0.24455287855815028j)
# (14.265822560858739+0.24535148495522474j)
# (14.30577963694276+0.24615011680956303j)
# (14.34573733702657+0.2469487736181369j)
# (14.38569564877008+0.24774745488783392j)
# (14.425654560076836+0.24854616013526282j)
# (14.465614059089242+0.24934488888656312j)
# (14.505574134183846+0.2501436406772176j)
# (14.545534773966724+0.25094241505186904j)
# (14.585495967268969+0.25174121156414037j)
# (14.625457703142258+0.2525400297764579j)
# (14.665419970854503+0.25333886925987936j)
# (14.705382759885588+0.25413772959392267j)
# (14.745346059923204+0.2549366103664014j)
# (14.785309860858742+0.255735511173261j)
# (14.825274152783287+0.25653443161841816j)
# (14.865238925983672+0.2573333713136059j)
# (14.905204170938635+0.2581323298782182j)
# (14.94516987831502+0.25893130693916033j)
# (14.985136038964086+0.25973030213070036j)
# (15.025102643917847+0.2605293150943253j)
# (15.065069684385538+0.26132834547859785j)
# (15.10503715175009+0.2621273929390183j)
# (15.145005037564724+0.2629264571378874j)
# (15.18497333354959+0.2637255377441725j)
# (15.224942031588466+0.26452463443337665j)
# (15.264911123725538+0.26532374688740945j)
# (15.304880602162232+0.2661228747944615j)
# (15.344850459254111+0.26692201784888026j)
# (15.384820687507837+0.2677211757510488j)
# (15.424791279578184+0.2685203482072672j)
# (15.464762228265121+0.26931953492963573j)
# (15.504733526510943+0.2701187356359409j)
# (15.544705167397463+0.27091795004954283j)
# (15.584677144143257+0.27171717789926614j)
# (15.62464945010096+0.2725164189192915j)
# (15.66462207875463+0.27331567284905084j)
# (15.704595023717143+0.27411493943312315j)
# (15.744568278727659+0.2749142184211336j)
# (15.784541837649114+0.27571350956765356j)
# (15.824515694465788+0.2765128126321032j)
# (15.86448984328091+0.2773121273786561j)
# (15.904464278314295+0.2781114535761455j)
# (15.944438993900055+0.2789107909979717j)
# (15.984413984484336+0.27971013942201295j)
# (16.024389244623098+0.28050949863053654j)
# (16.06436476897996+0.28130886841011227j)
# (16.104340552324057+0.2821082485515277j)
# (16.144316589527968+0.2829076388497047j)
# (16.184292875565664+0.28370703910361816j)
# (16.224269405510512+0.2845064491162156j)
# (16.264246174533298+0.2853058686943392j)
# (16.304223177900315+0.2861052976486486j)
# (16.34420041097146+0.2869047357935457j)
# (16.384177869198407+0.28770418294710076j)
# (16.42415554812277+0.28850363893097963j)
# (16.464133443374333+0.28930310357037314j)
# (16.504111550669307+0.29010257669392797j)
# (16.544089865808626+0.2909020581336769j)
# (16.584068384676264+0.29170154772497353j)
# (16.624047103237604+0.2925010453064258j)
# (16.664026017537807+0.29330055071983163j)
# (16.704005123700256+0.29410006381011666j)
# (16.743984417925002+0.2948995844252717j)
# (16.783963896487247+0.29569911241629243j)
# (16.82394355573585+0.29649864763712014j)
# (16.863923392091877+0.2972981899445834j)
# (16.903903402047185+0.29809773919834054j)
# (16.943883582163+0.2988972952608251j)
# (16.98386392906855+0.29969685799718926j)
# (17.023844439459737+0.3004964272752512j)
# (17.06382511009779+0.30129600296544207j)
# ...
# (145.0509360310521+2.7591491387891276j)
# (145.05133612053635+2.7591492198708547j)
# (145.0517284358615+2.759149297835057j)
# (145.0521131280248+2.759149372801639j)
# (145.05249034514804+2.759149444885916j)
# (145.05286023253004+2.759149514198786j)
# (145.0532229326983+2.7591495808469007j)
# (145.05357858545986+2.7591496449328226j)
# (145.0539273279512+2.7591497065551827j)
# (145.0542692946873+2.759149765808829j)
# (145.05460461761004+2.7591498227849725j)
# (145.0549334261356+2.7591498775713217j)
# (145.055255847201+2.75914993025222j)
# (145.0555720053102+2.7591499809087705j)
# (145.05588202257894+2.7591500296189624j)
# (145.05618601877916+2.759150076457787j)
# (145.05648411138247+2.7591501214973553j)
# (145.05677641560308+2.7591501648070036j)
# (145.0570630444397+2.7591502064534037j)
# (145.05734410871685+2.7591502465006634j)
# (145.05761971712556+2.7591502850104224j)
# (145.0578899762631+2.7591503220419495j)
# (145.0581549906724+2.759150357652232j)
# (145.0584148628803+2.7591503918960627j)
# (145.05866969343552+2.7591504248261245j)
# (145.0589195809457+2.7591504564930713j)
# (145.05916462211408+2.7591504869456056j)
# (145.05940491177506+2.7591505162305534j)
# (145.05964054292969+2.759150544392936j)
# (145.05987160678+2.7591505714760385j)
# (145.0600981927633+2.7591505975214776j)
# (145.06032038858507+2.759150622569266j)
# (145.0605382802521+2.759150646657872j)
# (145.0607519521045+2.7591506698242814j)
# (145.06096148684728+2.7591506921040523j)
# (145.06116696558138+2.7591507135313704j)
# (145.06136846783414+2.759150734139103j)
# (145.06156607158917+2.7591507539588487j)
# (145.0617598533157+2.7591507730209863j)
# (145.06194988799746+2.759150791354722j)
# (145.06213624916086+2.7591508089881343j)
# (145.062319008903+2.7591508259482165j)
# (145.06249823791862+2.759150842260922j)
# (145.06267400552716+2.7591508579512j)
# (145.06284637969887+2.7591508730430356j)
# (145.06301542708061+2.7591508875594895j)
# (145.06318121302132+2.75915090152273j)
# (145.06334380159666+2.759150914954069j)
# (145.0635032556336+2.759150927873996j)
# (145.06365963673426+2.7591509403022076j)
# (145.06381300529938+2.759150952257641j)
# (145.06396342055146+2.7591509637585j)
# (145.06411094055738+2.7591509748222856j)
# (145.0642556222506+2.759150985465823j)
# (145.06439752145297+2.759150995705286j)
# (145.06453669289607+2.7591510055562254j)
# (145.0646731902423+2.7591510150335887j)
# (145.06480706610537+2.759151024151747j)
# (145.06493837207063+2.7591510329245157j)
# (145.06506715871487+2.7591510413651767j)
# (145.06519347562568+2.7591510494864986j)
# (145.06531737142075+2.759151057300755j)
# (145.06543889376636+2.759151064819748j)
# (145.065558089396+2.7591510720548205j)
# (145.06567500412834+2.759151079016879j)
# (145.0657896828848+2.759151085716409j)
# (145.0659021697071+2.759151092163489j)
# (145.06601250777416+2.7591510983678096j)
# (145.06612073941895+2.7591511043386863j)
# (145.06622690614472+2.7591511100850754j)
# (145.06633104864125+2.7591511156155857j)
# (145.0664332068005+2.7591511209384953j)
# (145.0665334197322+2.759151126061761j)
# (145.06663172577893+2.759151130993034j)
# (145.06672816253115+2.7591511357396676j)
# (145.06682276684177+2.7591511403087337j)
# (145.06691557484035+2.7591511447070287j)
# (145.06700662194737+2.75915114894109j)
# (145.06709594288787+2.759151153017198j)
# (145.06718357170513+2.7591511569413947j)
# (145.06726954177378+2.7591511607194876j)
# (145.06735388581293+2.7591511643570588j)
# (145.06743663589887+2.759151167859477j)
# (145.06751782347771+2.759151171231903j)
# (145.06759747937753+2.759151174479298j)
# (145.0676756338205+2.7591511776064324j)
# (145.06775231643473+2.7591511806178928j)
# (145.0678275562657+2.759151183518089j)
# (145.06790138178795+2.759151186311259j)
# (145.0679738209158+2.759151189001481j)
# (145.06804490101467+2.759151191592673j)
# (145.06811464891163+2.7591511940886035j)
# (145.0681830909059+2.7591511964928954j)
# (145.06825025277917+2.7591511988090325j)
# (145.06831615980585+2.7591512010403636j)
# (145.0683808367628+2.759151203190109j)
# (145.06844430793925+2.759151205261366j)
# (145.06850659714613+2.7591512072571107j)
# (145.06856772772568+2.759151209180207j)
# (145.06862772256034+2.759151211033407j)
# (145.06868660408205+2.7591512128193587j)
# (145.06874439428077+2.759151214540606j)
# (145.06880111471344+2.759151216199597j)
# (145.06885678651219+2.7591512177986846j)
# (145.0689114303929+2.7591512193401324j)
# (145.06896506666314+2.7591512208261157j)
# (145.06901771523042+2.7591512222587276j)
# (145.06906939560974+2.7591512236399804j)
# (145.06912012693158+2.7591512249718093j)
# (145.06916992794925+2.759151226256075j)
# (145.0692188170463+2.7591512274945673j)
# (145.0692668122439+2.7591512286890065j)
# (145.06931393120792+2.7591512298410485j)
# (145.06936019125573+2.759151230952285j)
# (145.06940560936326+2.7591512320242466j)
# (145.06945020217162+2.759151233058405j)
# (145.06949398599372+2.7591512340561772j)
# (145.0695369768205+2.759151235018924j)
# (145.06957919032763+2.7591512359479555j)
# (145.06962064188141+2.759151236844532j)
# (145.06966134654502+2.7591512377098644j)
# (145.06970131908423+2.759151238545118j)
# (145.06974057397366+2.759151239351414j)
# (145.06977912540208+2.7591512401298304j)
# (145.0698169872783+2.7591512408814047j)
# (145.06985417323656+2.759151241607134j)
# (145.06989069664203+2.7591512423079783j)
# (145.06992657059598+2.75915124298486j)
# (145.06996180794104+2.7591512436386676j)
# (145.0699964212663+2.7591512442702553j)
# (145.07003042291228+2.759151244880445j)
# (145.0700638249758+2.7591512454700267j)
# (145.0700966393148+2.7591512460397607j)
# (145.07012887755315+2.75915124659038j)
# (145.07016055108497+2.759151247122587j)
# (145.0701916710795+2.7591512476370594j)
# (145.0702222484853+2.7591512481344496j)
# (145.07025229403467+2.7591512486153835j)
# (145.07028181824793+2.759151249080465j)
# (145.07031083143752+2.759151249530274j)
# (145.07033934371222+2.7591512499653694j)
# (145.07036736498105+2.7591512503862887j)
# (145.07039490495723+2.7591512507935487j)
# (145.0704219731621+2.7591512511876473j)
# (145.07044857892888+2.759151251569063j)
# (145.07047473140622+2.759151251938257j)
# (145.0705004395622+2.7591512522956725j)
# (145.07052571218748+2.759151252641737j)
# (145.07055055789905+2.7591512529768605j)
# (145.07057498514365+2.7591512533014395j)
# (145.07059900220096+2.7591512536158533j)
# (145.07062261718713+2.7591512539204692j)
# (145.07064583805777+2.75915125421564j)
# (145.0706686726113+2.759151254501704j)
# (145.07069112849192+2.7591512547789887j)
# (145.07071321319276+2.759151255047808j)
# (145.07073493405883+2.7591512553084656j)
# (145.07075629828987+2.7591512555612523j)
# (145.07077731294328+2.7591512558064486j)
# (145.07079798493695+2.7591512560443254j)
# (145.07081832105197+2.759151256275142j)
# (145.0708383279354+2.75915125649915j)
# (145.07085801210278+2.7591512567165895j)
# (145.07087737994084+2.7591512569276935j)
# (145.07089643771+2.759151257132685j)
# (145.0709151915469+2.759151257331779j)
# (145.07093364746683+2.759151257525184j)
# (145.0709518113661+2.7591512577130994j)
# (145.07096968902437+2.7591512578957174j)
# (145.070987286107+2.7591512580732234j)
# (145.07100460816739+2.759151258245796j)
# (145.071021660649+2.7591512584136066j)
# (145.0710384488876+2.7591512585768214j)
# (145.07105497811358+2.7591512587355997j)
# (145.07107125345362+2.7591512588900953j)
# (145.07108727993318+2.759151259040456j)
# (145.07110306247824+2.7591512591868246j)
# (145.07111860591735+2.759151259329338j)
# (145.07113391498353+2.75915125946813j)
# (145.0711489943162+2.759151259603327j)
# (145.07116384846285+2.7591512597350523j)
# (145.0711784818812+2.7591512598634242j)
# (145.07119289894067+2.7591512599885575j)
# (145.07120710392425+2.7591512601105617j)
# (145.07122110103018+2.7591512602295434j)
# (145.07123489437367+2.7591512603456043j)
# (145.07124848798844+2.759151260458844j)
# (145.07126188582845+2.759151260569356j)
# (145.07127509176942+2.7591512606772337j)
# (145.07128810961035+2.759151260782564j)
# (145.0713009430751+2.7591512608854325j)
# (145.07131359581382+2.7591512609859214j)
# (145.07132607140443+2.75915126108411j)
# (145.07133837335402+2.7591512611800746j)
# (145.07135050510036+2.7591512612738884j)
# (145.07136247001313+2.7591512613656226j)
# (145.07137427139529+2.7591512614553464j)
# (145.07138591248454+2.7591512615431246j)
# (145.07139739645442+2.7591512616290226j)
# (145.07140872641563+2.7591512617131j)
# (145.0714199054174+2.759151261795418j)
# (145.07143093644856+2.759151261876032j)
# (145.07144182243883+2.7591512619549987j)
# (145.07145256625986+2.75915126203237j)
# (145.07146317072656+2.759151262108199j)
# (145.07147363859806+2.759151262182534j)
# (145.07148397257887+2.7591512622554237j)
# (145.07149417532003+2.7591512623269137j)
# (145.0715042494201+2.759151262397049j)
# (145.0715141974261+2.7591512624658723j)
# (145.0715240218348+2.7591512625334254j)
# (145.0715337250934+2.7591512625997483j)
# (145.07154330960074+2.7591512626648806j)
# (145.07155277770818+2.759151262728859j)
# (145.0715621317205+2.7591512627917196j)
# (145.07157137389692+2.7591512628534973j)
# (145.0715805064518+2.759151262914226j)
# (145.07158953155582+2.7591512629739388j)
# (145.07159845133657+2.759151263032666j)
# (145.07160726787959+2.7591512630904385j)
# (145.07161598322915+2.7591512631472863j)
# (145.07162459938903+2.7591512632032367j)
# (145.0716331183233+2.759151263258318j)
# (145.07164154195715+2.7591512633125563j)
# (145.07164987217777+2.759151263365977j)
# (145.07165811083487+2.7591512634186057j)
# (145.07166625974156+2.759151263470465j)
# (145.0716743206751+2.759151263521579j)
# (145.0716822953775+2.75915126357197j)
# (145.07169018555638+2.7591512636216593j)
# (145.07169799288542+2.759151263670668j)
# (145.0717057190053+2.759151263719016j)
# (145.07171336552415+2.7591512637667237j)
# (145.0717209340182+2.759151263813809j)
# (145.07172842603262+2.759151263860291j)
# (145.07173584308185+2.7591512639061873j)
# (145.07174318665042+2.759151263951514j)
# (145.07175045819346+2.759151263996289j)
# (145.07175765913726+2.759151264040528j)
# (145.07176479087988+2.7591512640842457j)
# (145.07177185479173+2.7591512641274583j)
# (145.07177885221606+2.759151264170179j)
# (145.0717857844695+2.759151264212423j)
# (145.0717926528427+2.759151264254204j)
# (145.07179945860065+2.759151264295534j)
# (145.07180620298334+2.7591512643364267j)
# (145.07181288720622+2.7591512643768943j)
# (145.07181951246065+2.7591512644169485j)
# (145.07182607991442+2.759151264456601j)
# (145.07183259071215+2.7591512644958636j)
# (145.07183904597588+2.7591512645347462j)
# (145.07184544680536+2.7591512645732603j)
# (145.07185179427856+2.759151264611415j)
# (145.0718580894522+2.759151264649222j)
# (145.07186433336196+2.7591512646866887j)
# (145.07187052702307+2.7591512647238257j)
# (145.07187667143066+2.759151264760642j)
# (145.07188276756014+2.7591512647971457j)
# (145.07188881636762+2.759151264833346j)
# (145.07189481879024+2.7591512648692507j)
# (145.07190077574663+2.759151264904868j)
# (145.07190668813718+2.7591512649402055j)
# (145.0719125568445+2.7591512649752703j)
# (145.0719183827337+2.7591512650100705j)
# (145.0719241666528+2.7591512650446126j)
# (145.0719299094329+2.7591512650789034j)
# (145.0719356118888+2.7591512651129495j)
# (145.07194127481907+2.759151265146758j)
# (145.07194689900646+2.7591512651803343j)
# (145.07195248521833+2.759151265213685j)
# (145.07195803420672+2.7591512652468153j)
# (145.07196354670882+2.759151265279732j)
# (145.07196902344722+2.75915126531244j)
# (145.07197446513024+2.759151265344945j)
# (145.07197987245212+2.7591512653772514j)
# (145.07198524609336+2.7591512654093653j)
# (145.071990586721+2.7591512654412913j)
# (145.07199589498885+2.759151265473034j)
# (145.07200117153783+2.759151265504598j)
# (145.07200641699606+2.7591512655359884j)
# (145.07201163197936+2.7591512655672092j)
# (145.07201681709128+2.7591512655982644j)
# (145.07202197292335+2.7591512656291584j)
# (145.0720271000555+2.759151265659895j)
# (145.07203219905608+2.7591512656904786j)
# (145.07203727048235+2.7591512657209134j)
# (145.0720423148803+2.7591512657512016j)
# (145.0720473327853+2.759151265781348j)
# (145.072052324722+2.759151265811356j)
# (145.07205729120471+2.7591512658412287j)
# (145.0720622327376+2.7591512658709694j)
# (145.07206714981476+2.7591512659005812j)
# (145.07207204292052+2.7591512659300674j)
# (145.07207691252967+2.7591512659594315j)
# (145.07208175910753+2.7591512659886757j)
# (145.0720865831103+2.759151266017804j)
# (145.07209138498504+2.759151266046818j)
# (145.07209616517002+2.7591512660757207j)
# (145.0721009240948+2.7591512661045154j)
# (145.07210566218043+2.759151266133204j)
# (145.0721103798397+2.7591512661617896j)
# (145.0721150774771+2.759151266190274j)
# (145.07211975548918+2.75915126621866j)
# (145.07212441426464+2.75915126624695j)
# (145.07212905418444+2.759151266275146j)
# (145.0721336756221+2.7591512663032502j)
# (145.07213827894358+2.759151266331265j)
# (145.07214286450773+2.7591512663591926j)
# (145.07214743266618+2.7591512663870343j)
# (145.07215198376377+2.759151266414793j)
# (145.0721565181383+2.7591512664424704j)
# (145.07216103612103+2.7591512664700684j)
# (145.0721655380366+2.759151266497588j)
# (145.0721700242032+2.759151266525032j)
# (145.07217449493277+2.759151266552402j)
# (145.07217895053103+2.7591512665796993j)
# (145.0721833912977+2.759151266606926j)
# (145.07218781752653+2.759151266634084j)
# (145.0721922295054+2.7591512666611733j)
# (145.0721966275166+2.7591512666881974j)
# (145.07220101183674+2.7591512667151563j)
# (145.07220538273697+2.7591512667420526j)
# (145.0722097404831+2.7591512667688867j)
# (145.07221408533564+2.759151266795661j)
# (145.07221841754998+2.759151266822376j)
# (145.0722227373764+2.7591512668490332j)
# (145.0722270450603+2.7591512668756346j)
# (145.07223134084208+2.7591512669021805j)
# (145.07223562495756+2.7591512669286726j)
# (145.0722398976378+2.759151266955112j)
# (145.0722441591092+2.7591512669815j)
# (145.07224840959384+2.7591512670078377j)
# (145.0722526493093+2.7591512670341265j)
# (145.07225687846886+2.7591512670603664j)
# (145.0722610972816+2.75915126708656j)
# (145.07226530595244+2.7591512671127076j)
# (145.07226950468225+2.75915126713881j)
# (145.07227369366794+2.7591512671648686j)
# (145.07227787310245+2.7591512671908838j)
# (145.07228204317502+2.7591512672168568j)
# (145.07228620407102+2.759151267242789j)
# (145.0722903559722+2.759151267268681j)
# (145.07229449905674+2.7591512672945333j)
# (145.07229863349926+2.759151267320347j)
# (145.0723027594709+2.759151267346123j)
# (145.07230687713943+2.759151267371862j)
# (145.07231098666932+2.7591512673975656j)
# (145.07231508822179+2.759151267423233j)
# (145.07231918195475+2.7591512674488663j)
# (145.07232326802315+2.759151267474466j)
# (145.07232734657876+2.759151267500032j)
# (145.0723314177704+2.7591512675255663j)
# (145.07233548174395+2.7591512675510685j)
# (145.07233953864232+2.7591512675765397j)
# (145.07234358860566+2.7591512676019807j)
# (145.07234763177132+2.759151267627392j)
# (145.07235166827394+2.7591512676527743j)
# (145.0723556982455+2.759151267678128j)
# (145.0723597218153+2.7591512677034533j)
# (145.07236373911022+2.759151267728752j)
# (145.07236775025447+2.759151267754024j)
# (145.0723717553699+2.75915126777927j)
# (145.0723757545759+2.7591512678044903j)
# (145.07237974798954+2.7591512678296852j)
# (145.0723837357255+2.759151267854856j)
# (145.07238771789628+2.7591512678800028j)
# (145.0723916946121+2.759151267905126j)
# (145.072395665981+2.7591512679302266j)
# (145.07239963210884+2.7591512679553043j)
# (145.07240359309944+2.7591512679803607j)
# (145.0724075490546+2.759151268005395j)
# (145.072411500074+2.759151268030408j)
# (145.0724154462554+2.7591512680554007j)
# (145.07241938769465+2.759151268080373j)
# (145.07242332448567+2.7591512681053256j)
# (145.0724272567205+2.759151268130259j)
# (145.07243118448937+2.7591512681551733j)
# (145.07243510788078+2.7591512681800685j)
# (145.07243902698139+2.759151268204946j)
# (145.07244294187623+2.7591512682298056j)
# (145.07244685264854+2.7591512682546475j)
# (145.07245075938002+2.759151268279473j)
# (145.07245466215068+2.759151268304281j)
# (145.07245856103899+2.759151268329073j)
# (145.0724624561218+2.759151268353849j)
# (145.07246634747452+2.7591512683786092j)
# (145.07247023517104+2.759151268403354j)
# (145.07247411928373+2.7591512684280834j)
# (145.0724779998836+2.7591512684527983j)
# (145.07248187704022+2.759151268477499j)
# (145.07248575082178+2.7591512685021855j)
# (145.07248962129512+2.7591512685268578j)
# (145.07249348852582+2.7591512685515167j)
# (145.07249735257807+2.7591512685761623j)
# (145.0725012135148+2.759151268600795j)
# (145.07250507139776+2.7591512686254145j)
# (145.07250892628738+2.759151268650022j)
# (145.072512781177+2.7591512686254145j)

# %% [markdown]
# ## Later work?

# %%
def quantum_gate_braid_protocol(gate:str="X",N:int = 2, T:float = 20.0, dt:float = 0.01 ,delta_max:float = 100.0, delta_min:float = 0.1, s:float = 10.0):
    """Compute the braiding protocol for a given quantum gate.
    N fermions are used to create 2**N majorana operators.
    Then the right braiding operators are aquired for the given gate.
    Then the corresponding Hamiltonian is constructed.
    The Hamiltonian is then used to compute the time evolution of the system. 

    Args:
    gate (str): The quantum gate to be implemented. Options are "X", "Y", "Z", or "Hadamard".
    N (int): The number of fermions used to create the Majorana operators.
        - Minimum value is 2 (Later will be 3, 2 for the gate recreation and 1 for the readout)
    T (float): The total time for the braiding protocol.
    dt (float): The time step for the time evolution.
    delta_max (float): The maximum value of the delta function.
    delta_min (float): The minimum value of the delta function.
    s (float): The parameter s for the delta function.

    """

    # Create Majorana operators
    gammas = []
    for i in range(N):
        g1, g2 = majorana_ops(i, N)
        gammas.append(g1)
        gammas.append(g2)
    gammas = np.array(gammas)

    # Define the braiding operators
    gate_to_braids = {
        "X": [(1,2), (1,2)],
        "Y": [(0,2), (0,2)],
        "Z": [(0,1), (0,1)],
        "Hadamard": [(0,1), (1,2), (0,1)]
    }

    braids = gate_to_braids.get(gate)
    
    #Create braiding operators and the needed gamma operators
    braiding_ops = []
    braiding_gammas = []
    for braid in braids:
        i, j = braid
        b = braiding_operators(gammas[i], gammas[j])
        g = gammas[i] @ gammas[j]

        braiding_ops.append(b)
        braiding_gammas.append(g)

    def H_t(t:np.ndarray,T_braid:float,s:float,delta_max:float,delta_min:float) -> float:
        """
        Returns the Hamiltonian for a given time T and s
        """
        H = np.zeros((2**N, 2**N), dtype=complex)
        for b in range(len(braiding_ops)):
            #T_braid, time of braid, evenly spaced in the time interval
            T_braid = T/(len(braiding_ops) + 1 ) * (b+1)
            H += braiding_gammas[b] * delta(t, T_braid, s, delta_max, delta_min)
        return H


    
    H = H_t(0, T, delta_max, delta_min, s)

    # Find the eigenvalues and eigenvectors of the Hamiltonian
    e_vals, e_vecs = np.linalg.eigh(H)
    Psi = np.zeros((int(T/dt), 2**N), dtype=complex)
    Psi[0] = e_vecs[:, 0]  # Ground state

    # Norm of the wavefunction
    norms = np.zeros(int(T/dt))
    norms[0] = np.linalg.norm(Psi[0])


    # Time evolution
    time_array = np.linspace(0, T, int(T/dt))
    for i in range(1,len(time_array)):
        # Create the Hamiltonian at time t
        H = H_t(time_array[i], T, delta_max, delta_min, s)
        # Update the wavefunction
        Psi[i] = Psi[i-1] + 1j * H @ Psi[i-1] * dt
        # Normalize the wavefunction
        norm = np.linalg.norm(Psi[i])
        Psi[i] /= norm
        norms[i] = norm
    

    return Psi, norms, time_array
Psi, norms, times = quantum_gate_braid_protocol("Hadamard")  




plt.figure(figsize=(12, 6))
plt.plot(times, norms)
plt.xlabel('Time', fontsize=12)
plt.ylabel('Norm', fontsize=12)
plt.title('Norm of the wavefunction', fontsize=12)
plt.axhline(1, color='r', linestyle='--', label='Norm = 1')
plt.legend()
plt.show()

plt.figure(figsize=(12, 6))
plt.axhline(1, color='r', linestyle='--', label='Norm = 1')
plt.plot(times,np.abs(Psi[:,0]**2), label=f'⟨00|00⟩= {np.mean(np.abs(Psi[:,0])**2):.2f}')
plt.plot(times, np.abs(Psi[:,1])**2, label=f'⟨01|01⟩= {np.mean(np.abs(Psi[:,1])**2):.2f}')
plt.plot(times, np.abs(Psi[:,2])**2, label=f'⟨10|10⟩= {np.mean(np.abs(Psi[:,2])**2):.2f}')
plt.plot(times, np.abs(Psi[:,3])**2, label=f'⟨11|11⟩= {np.mean(np.abs(Psi[:,3])**2):.2f}')
plt.plot(times, np.linalg.norm(Psi,axis=1)**2, label=f'|psi|^2= {np.mean(np.linalg.norm(Psi,axis=1)**2):.1f}')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Probability', fontsize=12)
plt.ylim(-0.1, 1.2)
plt.title('Probability of the wavefunction', fontsize=12)
plt.legend( loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 88
#      84         norms[i] = norm
#      87     return Psi, norms, time_array
# ---> 88 Psi, norms, times = quantum_gate_braid_protocol("Hadamard")
#      93 plt.figure(figsize=(12, 6))
#      94 plt.plot(times, norms)
#
# Cell In[9], line 62, in quantum_gate_braid_protocol(gate, N, T, dt, delta_max, delta_min, s)
#      57         H += braiding_gammas[b] * delta(t, T_braid, s, delta_max, delta_min)
#      58     return H
# ---> 62 H = H_t(0, T, delta_max, delta_min, s)
#      64 # Find the eigenvalues and eigenvectors of the Hamiltonian
#      65 e_vals, e_vecs = np.linalg.eigh(H)
#
# Cell In[9], line 57, in quantum_gate_braid_protocol.<locals>.H_t(t, T_braid, s, delta_max, delta_min)
#      54 for b in range(len(braiding_ops)):
#      55     #T_braid, time of braid, evenly spaced in the time interval
#      56     T_braid = T/(len(braiding_ops) + 1 ) * (b+1)
# ---> 57     H += braiding_gammas[b] * delta(t, T_braid, s, delta_max, delta_min)
#      58 return H
#
# NameError: name 'delta' is not defined
